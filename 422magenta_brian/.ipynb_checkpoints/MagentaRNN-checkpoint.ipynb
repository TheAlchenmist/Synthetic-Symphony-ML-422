# %% [markdown]
# # Magenta RNN
#
# In this notebook, we will be generating three basic melodies using Magenta and it's three models. Magenta usesa Recurring Nural Network, or RNN, to generate it's music. RNN's are a class of feedforward Neural Networks where nodes form a connected graph along of a temporal sequence.

# %%
import math
import os
import time
import warnings

def action_with_warning():
    warnings.warn("should not appear")

with warnings.catch_warnings(record=True):
    action_with_warning()
    
import magenta.music as mm
from magenta.models.melody_rnn import melody_rnn_sequence_generator
from magenta.music import DEFAULT_QUARTERS_PER_MINUTE
from magenta.protobuf.generator_pb2 import GeneratorOptions
from magenta.protobuf.music_pb2 import NoteSequence
from visual_midi import Plotter

def generate(bundle_name: str,
             sequence_generator,
             generator_id: str,
             primer_filename: str = None,
             qpm: float = DEFAULT_QUARTERS_PER_MINUTE,
             total_length_steps: int = 64,
             temperature: float = 1.0,
             beam_size: int = 1,
             branch_factor: int = 1,
             steps_per_iteration: int = 1,
             generatedname = str,
             show_plot: bool = False) -> NoteSequence:
    mm.notebook_utils.download_bundle(bundle_name, "bundles")
    bundle = mm.sequence_generator_bundle.read_bundle_file(os.path.join("bundles", bundle_name))
    generator_map = sequence_generator.get_generator_map()
    generator = generator_map[generator_id](checkpoint=None, bundle=bundle)
    generator.initialize()
    if primer_filename:
        primer_sequence = mm.midi_io.midi_file_to_note_sequence(
          os.path.join("simplemidi", primer_filename))
    else:
        primer_sequence = NoteSequence()
    if primer_sequence.tempos:
        if len(primer_sequence.tempos) > 1:
          raise Exception("No support for multiple tempos")
        qpm = primer_sequence.tempos[0].qpm
    # Calculates the seconds per 1 step, which changes depending on the QPM 
    # value (steps per quarter in generators are mostly 4)
    seconds_per_step = 60.0 / qpm / getattr(generator, "steps_per_quarter", 4)
  
    # Calculates the primer sequence length in steps and time by taking the
    # total time (which is the end of the last note) and finding the next step
    # start time.
    primer_sequence_length_steps = math.ceil(primer_sequence.total_time
                                             / seconds_per_step)
    primer_sequence_length_time = (primer_sequence_length_steps 
                                   * seconds_per_step)
    primer_end_adjust = (0.00001 if primer_sequence_length_time > 0 else 0)
    primer_start_time = 0
    primer_end_time = (primer_start_time
                       + primer_sequence_length_time
                       - primer_end_adjust)
    generation_length_steps = total_length_steps - primer_sequence_length_steps
    if generation_length_steps <= 0:
        raise Exception("Total length in steps too small "
                        + "(" + str(total_length_steps) + ")"
                        + ", needs to be at least one bar bigger than primer "
                        + "(" + str(primer_sequence_length_steps) + ")")
    generation_length_time = generation_length_steps * seconds_per_step
    generation_start_time = primer_end_time
    generation_end_time = (generation_start_time
                           + generation_length_time
                           + primer_end_adjust)
  
    # Showtime
    print("Primer time: ["
          + str(primer_start_time) + ", "
          + str(primer_end_time) + "]")
    print("Generation time: ["
          + str(generation_start_time) + ", "
          + str(generation_end_time) + "]")
    generator_options = GeneratorOptions()
    generator_options.args['temperature'].float_value = temperature
    generator_options.args['beam_size'].int_value = beam_size
    generator_options.args['branch_factor'].int_value = branch_factor
    generator_options.args['steps_per_iteration'].int_value = (
        steps_per_iteration)
    generator_options.generate_sections.add(
        start_time=generation_start_time,
        end_time=generation_end_time)
    sequence = generator.generate(primer_sequence, generator_options)
    
    date_and_time = time.strftime('%Y-%m-%d_%H%M%S')
    generator_name = str(generator.__class__).split(".")[2]
    midi_filename = "%s.mid" % (generatedname)
    midi_path = os.path.join("output", midi_filename)
    mm.midi_io.note_sequence_to_midi_file(sequence, midi_path)
    print("Generated midi file: " + str(os.path.abspath(midi_path)))
  
    # Writes the resulting plot file to the output directory
    date_and_time = time.strftime('%Y-%m-%d_%H%M%S')
    generator_name = str(generator.__class__).split(".")[2]
    plot_filename = "%s.html" % (generatedname)
    plot_path = os.path.join("output", plot_filename)
    pretty_midi = mm.midi_io.note_sequence_to_pretty_midi(sequence)
    plotter = Plotter()
    if show_plot:
        plotter.show(pretty_midi, plot_path)
    else:
        plotter.save(pretty_midi, plot_path)
    print("Generated plot file: " + str(os.path.abspath(plot_path)))
      
    return sequence
  
warnings.filterwarnings("ignore")
# Out:
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/magenta/music/note_sequence_io.py:60: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/magenta/pipelines/statistics.py:132: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %% [markdown]
# This method, generate, takes a RNN function and a midi, and returns a midi generated using said specified model. When generate is called, it takes in several parameters that affect how the music is generated.
# <br>
# <br>
# RNN model: The RNN model that is being used (i.e basic, lookback, or attention)
# <br>
# total_length_step: The length of the sequence of the produced new song. The total new length of the song will be the length of the song that is provided as data, as well as length specified here
# <br>
# qpm: the quarters per minute of music. The default is 60 qpm
# <br>
# temperature: the randomness of the generated melody. <1 is less random and more like the primer melody, while >1 is more random.
# <br>
# beam size: the larger the beam size, the less random the sequence will be, at the cost of time
# <br>
# steps_per_iteration: # of steps at each iteratiron, the larger this value, the less iterations there are in total

# %% [markdown]
# ## Basic RNN
#
# This model is Magenta standard RNN model. As you can see, in this model, the primer melody is not reflected much in the generated music after. This is because the basic RNN configuration uses one-hot coding to represent extected melodies in the LSTM. It can generate a short melody that stays in the key of the sample meoldy, but it has trouble meeking the same feeling and tone of the music, which a human composer would be able to do. Basic RNN is not able to observe and catalogue patterns in music, and thus generate music that does not share many of the music elements that the primer melody has. Basic RNN is not very holistic, and does not concider groups of notes and the small melodies that they create, and instead is more focused on trying to represent the note-by-note changes.
# <br>
# Basic RNN uses two features, inputs and labels, to generate melodies. The input is the previous event, aka the previous note measure, as a vector. The label is the next event, which can either be turning off (not playing anything), no event (if a note is currently playing, continue playing said note, else continue scilence), and a note-on event for every pitch (which also turns off any other note that might be playing). Based on what they input is, the model will select an event that is not too dissimilar from the previous event to make a following note that sounds somewhat similar to the previous note. By chaining these events together, this method forms a new song.

# %%
sequence = generate(
    "basic_rnn.mag",
    melody_rnn_sequence_generator,
    "basic_rnn",
    primer_filename="fur_elis.mid",
    total_length_steps=128,
    temperature=1,
    generatedname = "fur_elis_basic_rnn",
    show_plot=False)
from IPython.display import HTML
HTML(filename="output/fur_elis_basic_rnn.html")
# Out:
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/magenta/music/notebook_utils.py:196: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/magenta/music/sequence_generator_bundle.py:30: The name tf.gfile.Open is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/magenta/music/model.py:70: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/magenta/music/model.py:71: The name tf.train.import_meta_graph is deprecated. Please use tf.compat.v1.train.import_meta_graph instead.
#
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from /var/folders/dm/3kslprps6b736vz2bgdqpwx00000gn/T/tmpaseybpi2/model.ckpt
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/magenta/music/sequence_generator.py:159: The name tf.gfile.DeleteRecursively is deprecated. Please use tf.io.gfile.rmtree instead.
#
# Primer time: [0, 1.6463307499999995]
# Generation time: [1.6463307499999995, 23.414623999999993]
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -220.210480
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/magenta/music/midi_io.py:220: The name tf.gfile.Copy is deprecated. Please use tf.io.gfile.copy instead.
#
# Generated midi file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/fur_elis_basic_rnn.mid
# Generated plot file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/fur_elis_basic_rnn.html
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Plot</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-1.4.0.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="f11bc913-76b9-458b-b7ba-15820b51c23e" data-root-id="1121"></div>
#
#
#
#
#
#         <script type="application/json" id="1182">
#           {"afc577e6-a7f9-48b3-a288-5458fcecafc7":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.25},"fill_color":{"value":"gray"},"left":0.0,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":2.926827999999999},"id":"1073","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":0.0,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":0.7317069999999998},"id":"1081","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.05},"fill_color":{"value":"gray"},"left":20.487796,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":23.414624},"id":"1080","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":2.1951209999999994,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":2.926827999999999},"id":"1084","type":"BoxAnnotation"},{"attributes":{"callback":null,"tooltips":[["program","@program"],["pitch","@top"],["velocity","@velocity"],["duration","@duration"],["start_time","@left"],["end_time","@right"]]},"id":"1021","type":"HoverTool"},{"attributes":{"fill_color":{"value":null},"left":1.4634139999999995,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":2.1951209999999994},"id":"1083","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":22.682917,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":23.414624},"id":"1112","type":"BoxAnnotation"},{"attributes":{},"id":"1022","type":"SaveTool"},{"attributes":{"render_mode":"css","text":"75","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":75.1},"id":"1056","type":"Label"},{"attributes":{"bottom":76,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":77},"id":"1057","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":0.7317069999999998,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":1.4634139999999995},"id":"1082","type":"BoxAnnotation"},{"attributes":{},"id":"1023","type":"WheelZoomTool"},{"attributes":{"interval":1},"id":"1115","type":"SingleIntervalTicker"},{"attributes":{},"id":"1024","type":"PanTool"},{"attributes":{"callback":null,"end":23.414623999999993},"id":"1119","type":"Range1d"},{"attributes":{"fill_color":{"value":null},"left":2.926827999999999,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":3.6585349999999988},"id":"1085","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"76","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":76.1},"id":"1058","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":3.6585349999999988,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":4.390241999999999},"id":"1086","type":"BoxAnnotation"},{"attributes":{"bottom":77,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":78},"id":"1059","type":"BoxAnnotation"},{"attributes":{"children":[{"id":"1001","subtype":"Figure","type":"Plot"}]},"id":"1121","type":"Column"},{"attributes":{"fill_color":{"value":null},"left":4.390241999999999,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":5.121948999999999},"id":"1087","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":5.121948999999999,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":5.853655999999999},"id":"1088","type":"BoxAnnotation"},{"attributes":{"callback":null,"end":84,"start":69},"id":"1120","type":"Range1d"},{"attributes":{"render_mode":"css","text":"77","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":77.1},"id":"1060","type":"Label"},{"attributes":{"bottom":78,"fill_alpha":{"value":0.15},"fill_color":{"value ...

# %%
sequence = generate(
    "basic_rnn.mag",
    melody_rnn_sequence_generator,
    "basic_rnn",
    primer_filename="got_melody.mid",
    total_length_steps=128,
    temperature=1,
    generatedname = "got_melody_basic_rnn",
    show_plot=False)
from IPython.display import HTML
HTML(filename="output/got_melody_basic_rnn.html")
# Out:
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from /var/folders/dm/3kslprps6b736vz2bgdqpwx00000gn/T/tmp_rgsthq3/model.ckpt
# Primer time: [0, 4.235282000000001]
# Generation time: [4.235282000000001, 22.588224]
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -192.351730
# Generated midi file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/got_melody_basic_rnn.mid
# Generated plot file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/got_melody_basic_rnn.html
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Plot</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-1.4.0.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="c2b88e2d-2b85-42c4-9ca2-179f88d6b2df" data-root-id="1293"></div>
#
#
#
#
#
#         <script type="application/json" id="1354">
#           {"c4d6928d-6732-4fde-91c9-21754399e8bd":{"roots":{"references":[{"attributes":{"fill_color":{"value":null},"left":17.647050000000007,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":18.352932000000006},"id":"1278","type":"BoxAnnotation"},{"attributes":{"bottom":64,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":65},"id":"1227","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":10.588230000000003,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":11.294112000000004},"id":"1268","type":"BoxAnnotation"},{"attributes":{"text":"Visual MIDI (85 QPM, 4/4)","text_font_size":{"value":"14px"}},"id":"1289","type":"Title"},{"attributes":{"fill_color":{"value":null},"left":14.823522000000008,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":15.529404000000008},"id":"1274","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"64","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":64.1},"id":"1228","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":6.352938,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":7.05882},"id":"1262","type":"BoxAnnotation"},{"attributes":{"callback":null,"data":{"bottom":[73,64,69,71,73,64,69,71,71,64,68,69,71,64,68,71,71,71,69,66,73,71,64,71,73,69,71,64,66,71,71,73,71,64,71,71,69,71,64,64,73,71,64,71,64,66,69,73,66,64,69,73,73,71,64,73,71,71,69,66,69,69,66,71,73,69,71,66,71,69,71,64,66,69,69,69,71,64,73,64,71,71,66,69,71,73,69,71,64,68,71,73],"color":["rgb(255, 255, 255)","rgb(162, 88, 232)","rgb(106, 0, 181)","rgb(141, 129, 217)","rgb(255, 255, 255)","rgb(162, 88, 232)","rgb(106, 0, 181)","rgb(141, 129, 217)","rgb(141, 129, 217)","rgb(162, 88, 232)","rgb(179, 0, 179)","rgb(106, 0, 181)","rgb(141, 129, 217)","rgb(162, 88, 232)","rgb(179, 0, 179)","rgb(141, 129, 217)","rgb(141, 129, 217)","rgb(141, 129, 217)","rgb(106, 0, 181)","rgb(173, 90, 215)","rgb(255, 255, 255)","rgb(141, 129, 217)","rgb(162, 88, 232)","rgb(141, 129, 217)","rgb(255, 255, 255)","rgb(106, 0, 181)","rgb(141, 129, 217)","rgb(162, 88, 232)","rgb(173, 90, 215)","rgb(141, 129, 217)","rgb(141, 129, 217)","rgb(255, 255, 255)","rgb(141, 129, 217)","rgb(162, 88, 232)","rgb(141, 129, 217)","rgb(141, 129, 217)","rgb(106, 0, 181)","rgb(141, 129, 217)","rgb(162, 88, 232)","rgb(162, 88, 232)","rgb(255, 255, 255)","rgb(141, 129, 217)","rgb(162, 88, 232)","rgb(141, 129, 217)","rgb(162, 88, 232)","rgb(173, 90, 215)","rgb(106, 0, 181)","rgb(255, 255, 255)","rgb(173, 90, 215)","rgb(162, 88, 232)","rgb(106, 0, 181)","rgb(255, 255, 255)","rgb(255, 255, 255)","rgb(141, 129, 217)","rgb(162, 88, 232)","rgb(255, 255, 255)","rgb(141, 129, 217)","rgb(141, 129, 217)","rgb(106, 0, 181)","rgb(173, 90, 215)","rgb(106, 0, 181)","rgb(106, 0, 181)","rgb(173, 90, 215)","rgb(141, 129, 217)","rgb(255, 255, 255)","rgb(106, 0, 181)","rgb(141, 129, 217)","rgb(173, 90, 215)","rgb(141, 129, 217)","rgb(106, 0, 181)","rgb(141, 129, 217)","rgb(162, 88, 232)","rgb(173, 90, 215)","rgb(106, 0, 181)","rgb(106, 0, 181)","rgb(106, 0, 181)","rgb(141, 129, 217)","rgb(162, 88, 232)","rgb(255, 255, 255)","rgb(162, 88, 232)","rgb(141, 129, 217)","rgb(141, 129, 217)","rgb(173, 90, 215)","rgb(106, 0, 181)","rgb(141, 129, 217)","rgb(255, 255, 255)","rgb(106, 0, 181)","rgb(141, 129, 217)","rgb(162, 88, 232)","rgb(179, 0, 179)","rgb(141, 129, 217)","rgb(255, 255, 255)"],"duration":[0.352941,0.352941,0.17647049999999997,0.17647050000000009,0.35294099999999995,0.35294099999999995,0.17647049999999997,0.1764705000000002,0.35294099999999995,0.35294099999999995,0.1764705000000002,0.17647049999999975,0.35294099999999995,0.35294099999999995,0.17647049999999975,0.17647050000000064,0.3529409999999995,0.17647050000000064,0.17647049999999975,0.17647049999999975,0.17647050000000064,0.17647049999999975,0.3529410000000004,0.3529409999999995,0. ...

# %% [markdown]
# As you can see, in the music generated in basic_rnn for Fur Elis and the Game of Thrones theme, the primer melody is not very evident in the music generated. The only recongnisable aspects of the music are the recycled notes, tempo, and the spacing of the notes which somewhat matches the melody. We will next use two different modified RNN methods that might give us a song that sounds more human and natural.

# %% [markdown]
# ## Lookback RNN
#
# Lookback RNN uses custom inputs and labels in order to train the model better. This specific method uses pattern recognition to generate notes in a less random way. It recognizes patters that occur in the primer melody by "looking back" at the melody one or two bars ago. Along with the same input and labels that basic RNN uses, Lookback RNN uses the previous events from 1 and 2 bars ago as aditional inputs. This gives the network more data points to find patterns, such as small melodies, and mirrored or constrasting melodies and cadences. Lookback RNN also uses the whether the last event was a repetition from the event from 1 or 2 bars ago as an input. This lets the program recognise repetition and determine which segements of the inputed music are single melodies.
# <br>
# In addition to new inouts, we also get more labels with Lookback. These labels, unlike the Basic RNN, look back even further, 1 and 2 bars ago. If the current event is repeating the same event, aka the same sequence of notes, from 2 or 1 bars ago, we use a label to mark that spot as a repetition. On an event where there is no repetition, Lookback marks it with a label as a specific melody. For example, if we have a melody where the third bar repeats the first or second bar, each label for the third bar will be labeled as a repeated melody. But if the fouth bar is a unique melody, it is marked as uniqle. Lookback uses these new labels and inputs to map out the general structure of the input song, and create a some that has more structure.

# %%
sequence = generate(
    "lookback_rnn.mag",
    melody_rnn_sequence_generator,
    "lookback_rnn",
    primer_filename="fur_elis.mid",
    total_length_steps=128,
    temperature=1,
    generatedname = "fur_elis_lookback_rnn",
    show_plot=False)
HTML(filename="output/fur_elis_lookback_rnn.html")
# Out:
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from /var/folders/dm/3kslprps6b736vz2bgdqpwx00000gn/T/tmp4r18ahqs/model.ckpt
# Primer time: [0, 1.6463307499999995]
# Generation time: [1.6463307499999995, 23.414623999999993]
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -149.850876
# Generated midi file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/fur_elis_lookback_rnn.mid
# Generated plot file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/fur_elis_lookback_rnn.html
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Plot</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-1.4.0.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="f46b99cb-2279-45aa-b187-9cbf1cc93d76" data-root-id="1489"></div>
#
#
#
#
#
#         <script type="application/json" id="1550">
#           {"6b469377-e34b-4ab9-ac29-136d0f48c373":{"roots":{"references":[{"attributes":{"render_mode":"css","text":"68","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":68.1},"id":"1398","type":"Label"},{"attributes":{"render_mode":"css","text":"81","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":81.1},"id":"1424","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":7.317069999999999,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":8.048777},"id":"1459","type":"BoxAnnotation"},{"attributes":{"dimension":1,"grid_line_color":null,"ticker":{"id":"1370","type":"BasicTicker"}},"id":"1373","type":"Grid"},{"attributes":{"bottom":86,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":87},"id":"1433","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":16.829261,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":17.560968},"id":"1472","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"1391","type":"ColumnDataSource"},"glyph":{"id":"1393","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1394","type":"Quad"},"selection_glyph":null,"view":{"id":"1396","type":"CDSView"}},"id":"1395","type":"GlyphRenderer"},{"attributes":{"render_mode":"css","text":"84","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":84.1},"id":"1430","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":8.048777,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":8.780484},"id":"1460","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"1364","type":"LinearAxis"}],"center":[{"id":"1368","type":"Grid"},{"id":"1373","type":"Grid"},{"id":"1397","type":"BoxAnnotation"},{"id":"1398","type":"Label"},{"id":"1399","type":"BoxAnnotation"},{"id":"1400","type":"Label"},{"id":"1401","type":"BoxAnnotation"},{"id":"1402","type":"Label"},{"id":"1403","type":"BoxAnnotation"},{"id":"1404","type":"Label"},{"id":"1405","type":"BoxAnnotation"},{"id":"1406","type":"Label"},{"id":"1407","type":"BoxAnnotation"},{"id":"1408","type":"Label"},{"id":"1409","type":"BoxAnnotation"},{"id":"1410","type":"Label"},{"id":"1411","type":"BoxAnnotation"},{"id":"1412","type":"Label"},{"id":"1413","type":"BoxAnnotation"},{"id":"1414","type":"Label"},{"id":"1415","type":"BoxAnnotation"},{"id":"1416","type":"Label"},{"id":"1417","type":"BoxAnnotation"},{"id":"1418","type":"Label"},{"id":"1419","type":"BoxAnnotation"},{"id":"1420","type":"Label"},{"id":"1421","type":"BoxAnnotation"},{"id":"1422","type":"Label"},{"id":"1423","type":"BoxAnnotation"},{"id":"1424","type":"Label"},{"id":"1425","type":"BoxAnnotation"},{"id":"1426","type":"Label"},{"id":"1427","type":"BoxAnnotation"},{"id":"1428","type":"Label"},{"id":"1429","type":"BoxAnnotation"},{"id":"1430","type":"Label"},{"id":"1431","type":"BoxAnnotation"},{"id":"1432","type":"Label"},{"id":"1433","type":"BoxAnnotation"},{"id":"1434","type":"Label"},{"id":"1435","type":"BoxAnnotation"},{"id":"1436","type":"Label"},{"id":"1437","type":"BoxAnnotation"},{"id":"1438","type":"Label"},{"id":"1439","type":"BoxAnnotation"},{"id":"1440","type":"Label"},{"id":"1441","type":"BoxAnnotation"},{"id":"1442","type":"BoxAnnotation"},{"id":"1443","type":"BoxAnnotation"},{"id":"1444","type":"BoxAnnotation"},{"id":"1445","type":"BoxAnnotation"},{"id":"1446","type":"BoxAnnotation"},{"id":"1447","type":"BoxAnnotation"},{"id":"1448","type":"BoxAnnotation"},{"id":"1449","type":"BoxAnnotation"},{"id":"1450","type":"BoxAnnotation"},{"id":"1451","type":"BoxAnnotation"},{"id":"1452","type":"BoxAnnotation"},{"id":"1453","type":"BoxAnnotation"},{"id":"1454","type":"BoxAnnotation"},{"id":"1455","type":"BoxAnnotation"},{"id":"1456","type":"BoxAnnotation"},{"id":"1457","type":"BoxAnnotation"},{"id":"1458","type":"BoxAnnotation"},{"id":"1459","type":"BoxAnnotation"},{"id":"1460","type":"BoxAnnotati ...

# %%
sequence = generate(
    "lookback_rnn.mag",
    melody_rnn_sequence_generator,
    "lookback_rnn",
    primer_filename="got_melody.mid",
    total_length_steps=128,
    temperature=1,
    generatedname = "got_melody_lookback_rnn",
    show_plot=False)
from IPython.display import HTML
HTML(filename="output/got_melody_lookback_rnn.html")
# Out:
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from /var/folders/dm/3kslprps6b736vz2bgdqpwx00000gn/T/tmpevga0_pw/model.ckpt
# Primer time: [0, 4.235282000000001]
# Generation time: [4.235282000000001, 22.588224]
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -205.388184
# Generated midi file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/got_melody_lookback_rnn.mid
# Generated plot file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/got_melody_lookback_rnn.html
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Plot</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-1.4.0.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="4ba7a408-a623-428b-b183-8ceac651b74e" data-root-id="1675"></div>
#
#
#
#
#
#         <script type="application/json" id="1736">
#           {"08cdbfad-7515-4686-9293-94de1fd4d5f1":{"roots":{"references":[{"attributes":{"fill_color":{"value":null},"left":16.23528600000001,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":16.941168000000008},"id":"1658","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":18.352932000000006,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":19.058814000000005},"id":"1661","type":"BoxAnnotation"},{"attributes":{"bottom":67,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":68},"id":"1601","type":"BoxAnnotation"},{"attributes":{},"id":"1680","type":"Selection"},{"attributes":{"bottom":{"field":"bottom"},"fill_color":{"field":"color"},"left":{"field":"left"},"right":{"field":"right"},"top":{"field":"top"}},"id":"1589","type":"Quad"},{"attributes":{"fill_color":{"value":null},"left":9.882348000000002,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":10.588230000000003},"id":"1649","type":"BoxAnnotation"},{"attributes":{"axis_label":"time (SEC)","axis_label_text_font_size":{"value":"12px"},"bounds":[0.0,22.588224],"formatter":{"id":"1585","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"10px"},"major_tick_line_alpha":{"value":0.9},"major_tick_out":5,"minor_tick_line_alpha":{"value":0},"ticker":{"id":"1667","type":"SingleIntervalTicker"}},"id":"1560","type":"LinearAxis"},{"attributes":{"bottom":74,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":75},"id":"1615","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":7.05882,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":7.764702},"id":"1645","type":"BoxAnnotation"},{"attributes":{"bottom":65,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":66},"id":"1597","type":"BoxAnnotation"},{"attributes":{"bottom":70,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":71},"id":"1607","type":"BoxAnnotation"},{"attributes":{"bottom":69,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":70},"id":"1605","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":16.941168000000008,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":17.647050000000007},"id":"1659","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"68","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":68.1},"id":"1604","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":2.117646,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":2.823528},"id":"1638","type":"BoxAnnotation"},{"attributes":{"bottom":64,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":65},"id":"1595","type":"BoxAnnotation"},{"attributes":{},"id":"1585","type":"BasicTickFormatter"},{"attributes":{"bottom":68,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":69},"id":"1603","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":21.176460000000002,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":21.882342},"id":"1665","type":"BoxAnnotation"},{"attributes":{"callback":null,"data":{"bottom":[73,64,69,71,73,64,69,71,71,64,68,69,71,64,68,71,68,64,73,72,71,71,73,76,73,69,80,73,76,71,68,73,78,69,73,78,76,78,73,71,71,78,76,68,76,73,78,76,76,78,76],"color":["rgb(255, 255, 255)","rgb(162, 88, 232)","rgb(106, 0, 181)","rgb(141, 129, 217)","rgb(255, 255, 255)","rgb(162, 88, 232)","rgb(106, 0, 181)","rgb(141, 129, 217)","rgb(141, 129, 217)","rgb(162, 88, 232)","rgb(179, 0 ...

# %% [markdown]
# As we can see, the two melodies that we created with lookback, comapred to the basic RNN, are much more structured. We can see that our algorithm understood which segments were unique and should be repeated. Unlike in Basic RNN, you could clearly hear the infulence of our primer music in the generated music. However, we can see that for some songs, like Fur Elis, Lookback makes our song too repetitive.

# %% [markdown]
# ## Attention RNN
#
# Attention RNN is a method where "attention" is given to specific parts of the sequence. In this Attention RNN version, where we don’t have an encoder-decoder, we just always look at the outputs from the last 𝑛 steps when generating the output for the current step. The way we “look at” these steps is with an attention mechanism. Specifically:
# <br>
# ![title](images/equation.png)
# <br>
#
# The vector 𝑣 and matrices 𝑊′1, 𝑊′2 are the learnable parameters of the model. ℎ𝑖 are the RNN outputs from the previous 𝑛 steps (ℎ𝑡−𝑛,...,ℎ𝑡−1), and vector 𝑐𝑡 is the current step’s RNN cell state. These are used to calculate 𝑢𝑡𝑖(𝑢𝑡𝑡−𝑛,...,𝑢𝑡𝑡−1), which is an 𝑛 length vector with a value for each of the previous 𝑛 steps. The values is how much attention each step should receive. A softmax is used to normalize these values and create a mask-like vector 𝑎𝑡𝑖, called the attention mask. The RNN outputs from the previous 𝑛 steps are then multiplied by these attention mask values and then summed together to get ℎ′𝑡. The ℎ′𝑡 vector is a vector of the 𝑛 previous outputs combined together, but each output contributing a different amount relative to how much attention that step received.
# <br>
# Using the h't vector, which combines the ouputs of the last n steps, lets Attention RNN injsect information from previous steps into the current step's calculation, letting Attention RNN learn longer-term patterns. It also stores the information from previous steps in the RNN's cell state.

# %%
sequence = generate(
    "attention_rnn.mag",
    melody_rnn_sequence_generator,
    "attention_rnn",
    primer_filename="fur_elis.mid",
    total_length_steps=128,
    temperature=1,
    generatedname = "fur_elis_attention_rnn",
    show_plot=False)
HTML(filename="output/fur_elis_attention_rnn.html")
# Out:
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from /var/folders/dm/3kslprps6b736vz2bgdqpwx00000gn/T/tmpo0rnu9tf/model.ckpt
# Primer time: [0, 1.6463307499999995]
# Generation time: [1.6463307499999995, 23.414623999999993]
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -201.808060
# Generated midi file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/fur_elis_attention_rnn.mid
# Generated plot file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/fur_elis_attention_rnn.html
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Plot</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-1.4.0.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="ee4a09a1-b840-4ffb-b5f1-a486a998dd39" data-root-id="1859"></div>
#
#
#
#
#
#         <script type="application/json" id="1920">
#           {"60b0dd2c-9b00-451c-8e23-da28e8dc7320":{"roots":{"references":[{"attributes":{"fill_color":{"value":null},"left":8.048777,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":8.780484},"id":"1830","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.25},"fill_color":{"value":"gray"},"left":17.560968,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":20.487796},"id":"1817","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":17.560968,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":18.292675},"id":"1843","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":15.365847,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":16.097554},"id":"1840","type":"BoxAnnotation"},{"attributes":{},"id":"1742","type":"LinearScale"},{"attributes":{"render_mode":"css","text":"78","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":78.1},"id":"1808","type":"Label"},{"attributes":{"bottom":67,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":68},"id":"1785","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":2.926827999999999,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":3.6585349999999988},"id":"1823","type":"BoxAnnotation"},{"attributes":{"bottom":76,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":77},"id":"1803","type":"BoxAnnotation"},{"attributes":{},"id":"1744","type":"LinearScale"},{"attributes":{"fill_color":{"value":null},"left":10.975605,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":11.707312},"id":"1834","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"1746","type":"LinearAxis"}],"center":[{"id":"1750","type":"Grid"},{"id":"1755","type":"Grid"},{"id":"1779","type":"BoxAnnotation"},{"id":"1780","type":"Label"},{"id":"1781","type":"BoxAnnotation"},{"id":"1782","type":"Label"},{"id":"1783","type":"BoxAnnotation"},{"id":"1784","type":"Label"},{"id":"1785","type":"BoxAnnotation"},{"id":"1786","type":"Label"},{"id":"1787","type":"BoxAnnotation"},{"id":"1788","type":"Label"},{"id":"1789","type":"BoxAnnotation"},{"id":"1790","type":"Label"},{"id":"1791","type":"BoxAnnotation"},{"id":"1792","type":"Label"},{"id":"1793","type":"BoxAnnotation"},{"id":"1794","type":"Label"},{"id":"1795","type":"BoxAnnotation"},{"id":"1796","type":"Label"},{"id":"1797","type":"BoxAnnotation"},{"id":"1798","type":"Label"},{"id":"1799","type":"BoxAnnotation"},{"id":"1800","type":"Label"},{"id":"1801","type":"BoxAnnotation"},{"id":"1802","type":"Label"},{"id":"1803","type":"BoxAnnotation"},{"id":"1804","type":"Label"},{"id":"1805","type":"BoxAnnotation"},{"id":"1806","type":"Label"},{"id":"1807","type":"BoxAnnotation"},{"id":"1808","type":"Label"},{"id":"1809","type":"BoxAnnotation"},{"id":"1810","type":"Label"},{"id":"1811","type":"BoxAnnotation"},{"id":"1812","type":"BoxAnnotation"},{"id":"1813","type":"BoxAnnotation"},{"id":"1814","type":"BoxAnnotation"},{"id":"1815","type":"BoxAnnotation"},{"id":"1816","type":"BoxAnnotation"},{"id":"1817","type":"BoxAnnotation"},{"id":"1818","type":"BoxAnnotation"},{"id":"1819","type":"BoxAnnotation"},{"id":"1820","type":"BoxAnnotation"},{"id":"1821","type":"BoxAnnotation"},{"id":"1822","type":"BoxAnnotation"},{"id":"1823","type":"BoxAnnotation"},{"id":"1824","type":"BoxAnnotation"},{"id":"1825","type":"BoxAnnotation"},{"id":"1826","type":"BoxAnnotation"},{"id":"1827","type":"BoxAnnotation"},{"id":"1828","type":"BoxAnnotation"},{"id":"1829","type":"BoxAnnotation"},{"id":"1830","type":"BoxAnnotation"},{"id":"1831","type":"BoxAnnotation"},{"id":"1832","type":"BoxAnnotation"},{"id":"1833","type":"BoxAnnotation"},{"id":"1834","type":"BoxAnnotation"},{"id":"1835","type":"BoxAn ...

# %%
sequence = generate(
    "attention_rnn.mag",
    melody_rnn_sequence_generator,
    "attention_rnn",
    primer_filename="got_melody.mid",
    total_length_steps=128,
    temperature=1,
    generatedname = "got_melody_attention_rnn",
    show_plot=False)
from IPython.display import HTML
HTML(filename="output/got_melody_attention_rnn.html")
# Out:
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from /var/folders/dm/3kslprps6b736vz2bgdqpwx00000gn/T/tmpxzuobgnz/model.ckpt
# Primer time: [0, 4.235282000000001]
# Generation time: [4.235282000000001, 22.588224]
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -133.299377
# Generated midi file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/got_melody_attention_rnn.mid
# Generated plot file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/got_melody_attention_rnn.html
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Plot</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-1.4.0.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="2fd58c9b-7c20-40c7-b8af-0defbaef7ec4" data-root-id="2039"></div>
#
#
#
#
#
#         <script type="application/json" id="2100">
#           {"96e22613-6eb1-4940-80f7-6949d13e6b24":{"roots":{"references":[{"attributes":{"fill_color":{"value":null},"left":11.294112000000004,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":11.999994000000004},"id":"2015","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":4.235292,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":4.941174},"id":"2005","type":"BoxAnnotation"},{"attributes":{"bottom":70,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":71},"id":"1979","type":"BoxAnnotation"},{"attributes":{"bottom":68,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":69},"id":"1975","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.25},"fill_color":{"value":"gray"},"left":11.294112000000004,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":14.117640000000003},"id":"1995","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"68","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":68.1},"id":"1976","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":18.352932000000006,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":19.058814000000005},"id":"2025","type":"BoxAnnotation"},{"attributes":{"bottom":69,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":70},"id":"1977","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"69","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":69.1},"id":"1978","type":"Label"},{"attributes":{"children":[{"id":"1921","subtype":"Figure","type":"Plot"}]},"id":"2039","type":"Column"},{"attributes":{"fill_color":{"value":null},"left":9.176466000000001,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":9.882348000000002},"id":"2012","type":"BoxAnnotation"},{"attributes":{"bottom":75,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":76},"id":"1989","type":"BoxAnnotation"},{"attributes":{},"id":"1942","type":"SaveTool"},{"attributes":{"fill_color":{"value":null},"left":8.470584,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":9.176466000000001},"id":"2011","type":"BoxAnnotation"},{"attributes":{},"id":"1936","type":"BasicTicker"},{"attributes":{"fill_color":{"value":null},"left":7.05882,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":7.764702},"id":"2009","type":"BoxAnnotation"},{"attributes":{"axis_label":"time (SEC)","axis_label_text_font_size":{"value":"12px"},"bounds":[0.0,22.588224],"formatter":{"id":"1955","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"10px"},"major_tick_line_alpha":{"value":0.9},"major_tick_out":5,"minor_tick_line_alpha":{"value":0},"ticker":{"id":"2031","type":"SingleIntervalTicker"}},"id":"1930","type":"LinearAxis"},{"attributes":{"fill_color":{"value":null},"left":6.352938,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":7.05882},"id":"2008","type":"BoxAnnotation"},{"attributes":{"axis_label":"pitch (MIDI)","axis_label_standoff":0,"axis_label_text_font_size":{"value":"12px"},"bounds":[62,76],"formatter":{"id":"1953","type":"BasicTickFormatter"},"major_label_text_alpha":{"value":0},"major_tick_line_alpha":{"value":0.9},"major_tick_out":25,"minor_tick_line_alpha":{"value":0},"ticker":{"id":"2033","type":"SingleIntervalTicker"}},"id":"1935","type":"LinearAxis"},{"attributes":{"bottom":{"field":"bottom"},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"1960","type":" ...

# %% [markdown]
# As we can see, the patterns that are repeated span a larger range with Attention RNN, and thus have more variance than Lookback brings. This creates a more natural sounding melody, as there is more variaton allowed, given the larger space that Attention gives to it's pattern detection.

# %% [markdown]
# ## Summary
#
# Through testing three RNN models, we have found that when learning how to train models to make music, we have to create a model that understand how to recognise patterns. The patterns that the model makes have to be recognizable in order to not be a random mess of notes, but also has to be hollistic enough to be able to not repeat too many patterns too frequently.
