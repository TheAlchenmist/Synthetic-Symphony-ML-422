# %% [markdown]
# # Magenta RNN
#
# In this notebook, we will be generating three basic melodies using Magenta and it's three models. Magenta usesa Recurring Nural Network, or RNN, to generate it's music. RNN's are a class of feedforward Neural Networks where nodes form a connected graph along of a temporal sequence.

# %%
import math
import os
import time
import warnings

def action_with_warning():
    warnings.warn("should not appear")

with warnings.catch_warnings(record=True):
    action_with_warning()
    
import magenta.music as mm
from magenta.models.melody_rnn import melody_rnn_sequence_generator
from magenta.music import DEFAULT_QUARTERS_PER_MINUTE
from magenta.protobuf.generator_pb2 import GeneratorOptions
from magenta.protobuf.music_pb2 import NoteSequence
from visual_midi import Plotter

def generate(bundle_name: str,
             sequence_generator,
             generator_id: str,
             primer_filename: str = None,
             qpm: float = DEFAULT_QUARTERS_PER_MINUTE,
             total_length_steps: int = 64,
             temperature: float = 1.0,
             beam_size: int = 1,
             branch_factor: int = 1,
             steps_per_iteration: int = 1,
             generatedname = str,
             show_plot: bool = False) -> NoteSequence:
    mm.notebook_utils.download_bundle(bundle_name, "bundles")
    bundle = mm.sequence_generator_bundle.read_bundle_file(os.path.join("bundles", bundle_name))
    generator_map = sequence_generator.get_generator_map()
    generator = generator_map[generator_id](checkpoint=None, bundle=bundle)
    generator.initialize()
    if primer_filename:
        primer_sequence = mm.midi_io.midi_file_to_note_sequence(
          os.path.join("simplemidi", primer_filename))
    else:
        primer_sequence = NoteSequence()
    if primer_sequence.tempos:
        if len(primer_sequence.tempos) > 1:
          raise Exception("No support for multiple tempos")
        qpm = primer_sequence.tempos[0].qpm
    # Calculates the seconds per 1 step, which changes depending on the QPM 
    # value (steps per quarter in generators are mostly 4)
    seconds_per_step = 60.0 / qpm / getattr(generator, "steps_per_quarter", 4)
  
    # Calculates the primer sequence length in steps and time by taking the
    # total time (which is the end of the last note) and finding the next step
    # start time.
    primer_sequence_length_steps = math.ceil(primer_sequence.total_time
                                             / seconds_per_step)
    primer_sequence_length_time = (primer_sequence_length_steps 
                                   * seconds_per_step)
    primer_end_adjust = (0.00001 if primer_sequence_length_time > 0 else 0)
    primer_start_time = 0
    primer_end_time = (primer_start_time
                       + primer_sequence_length_time
                       - primer_end_adjust)
    generation_length_steps = total_length_steps - primer_sequence_length_steps
    if generation_length_steps <= 0:
        raise Exception("Total length in steps too small "
                        + "(" + str(total_length_steps) + ")"
                        + ", needs to be at least one bar bigger than primer "
                        + "(" + str(primer_sequence_length_steps) + ")")
    generation_length_time = generation_length_steps * seconds_per_step
    generation_start_time = primer_end_time
    generation_end_time = (generation_start_time
                           + generation_length_time
                           + primer_end_adjust)
  
    # Showtime
    print("Primer time: ["
          + str(primer_start_time) + ", "
          + str(primer_end_time) + "]")
    print("Generation time: ["
          + str(generation_start_time) + ", "
          + str(generation_end_time) + "]")
    generator_options = GeneratorOptions()
    generator_options.args['temperature'].float_value = temperature
    generator_options.args['beam_size'].int_value = beam_size
    generator_options.args['branch_factor'].int_value = branch_factor
    generator_options.args['steps_per_iteration'].int_value = (
        steps_per_iteration)
    generator_options.generate_sections.add(
        start_time=generation_start_time,
        end_time=generation_end_time)
    sequence = generator.generate(primer_sequence, generator_options)
    
    date_and_time = time.strftime('%Y-%m-%d_%H%M%S')
    generator_name = str(generator.__class__).split(".")[2]
    midi_filename = "%s.mid" % (generatedname)
    midi_path = os.path.join("output", midi_filename)
    mm.midi_io.note_sequence_to_midi_file(sequence, midi_path)
    print("Generated midi file: " + str(os.path.abspath(midi_path)))
  
    # Writes the resulting plot file to the output directory
    date_and_time = time.strftime('%Y-%m-%d_%H%M%S')
    generator_name = str(generator.__class__).split(".")[2]
    plot_filename = "%s.html" % (generatedname)
    plot_path = os.path.join("output", plot_filename)
    pretty_midi = mm.midi_io.note_sequence_to_pretty_midi(sequence)
    plotter = Plotter()
    if show_plot:
        plotter.show(pretty_midi, plot_path)
    else:
        plotter.save(pretty_midi, plot_path)
    print("Generated plot file: " + str(os.path.abspath(plot_path)))
      
    return sequence
  
warnings.filterwarnings("ignore")

# %% [markdown]
# This method, generate, takes a RNN function and a midi, and returns a midi generated using said specified model. When generate is called, it takes in several parameters that affect how the music is generated.
# <br>
# <br>
# RNN model: The RNN model that is being used (i.e basic, lookback, or attention)
# <br>
# total_length_step: The length of the sequence of the produced new song. The total new length of the song will be the length of the song that is provided as data, as well as length specified here
# <br>
# qpm: the quarters per minute of music. The default is 60 qpm
# <br>
# temperature: the randomness of the generated melody. <1 is less random and more like the primer melody, while >1 is more random.
# <br>
# beam size: the larger the beam size, the less random the sequence will be, at the cost of time
# <br>
# steps_per_iteration: # of steps at each iteratiron, the larger this value, the less iterations there are in total

# %% [markdown]
# ## Basic RNN
#
# This model is Magenta standard RNN model. As you can see, in this model, the primer melody is not reflected much in the generated music after. This is because the basic RNN configuration uses one-hot coding to represent extected melodies in the LSTM. It can generate a short melody that stays in the key of the sample meoldy, but it has trouble meeking the same feeling and tone of the music, which a human composer would be able to do. Basic RNN is not able to observe and catalogue patterns in music, and thus generate music that does not share many of the music elements that the primer melody has. Basic RNN is not very holistic, and does not concider groups of notes and the small melodies that they create, and instead is more focused on trying to represent the note-by-note changes.
# <br>
# Basic RNN uses two features, inputs and labels, to generate melodies. The input is the previous event, aka the previous note measure, as a vector. The label is the next event, which can either be turning off (not playing anything), no event (if a note is currently playing, continue playing said note, else continue scilence), and a note-on event for every pitch (which also turns off any other note that might be playing). Based on what they input is, the model will select an event that is not too dissimilar from the previous event to make a following note that sounds somewhat similar to the previous note. By chaining these events together, this method forms a new song.

# %%
sequence = generate(
    "basic_rnn.mag",
    melody_rnn_sequence_generator,
    "basic_rnn",
    primer_filename="fur_elis.mid",
    total_length_steps=128,
    temperature=1,
    generatedname = "fur_elis_basic_rnn",
    show_plot=False)
from IPython.display import HTML
HTML(filename="output/fur_elis_basic_rnn.html")
# Out:
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from /var/folders/dm/3kslprps6b736vz2bgdqpwx00000gn/T/tmper6zu_aa/model.ckpt
# Primer time: [0, 1.6463307499999995]
# Generation time: [1.6463307499999995, 23.414623999999993]
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -189.158035
# Generated midi file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/fur_elis_basic_rnn.mid
# Generated plot file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/fur_elis_basic_rnn.html
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Plot</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-1.4.0.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="b01dac7e-855a-4cd5-89fa-d1ad474756a3" data-root-id="18176"></div>
#
#
#
#
#
#         <script type="application/json" id="18237">
#           {"40327035-1e96-410e-93e0-49f70308b51b":{"roots":{"references":[{"attributes":{"fill_color":{"value":null},"left":0.7317069999999998,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":1.4634139999999995},"id":"18138","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":19.756089,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":20.487796},"id":"18164","type":"BoxAnnotation"},{"attributes":{"bottom":68,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":69},"id":"18105","type":"BoxAnnotation"},{"attributes":{},"id":"18084","type":"PanTool"},{"attributes":{"fill_alpha":{"value":0.05},"fill_color":{"value":"gray"},"left":20.487796,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":23.414624},"id":"18136","type":"BoxAnnotation"},{"attributes":{},"id":"18080","type":"ResetTool"},{"attributes":{"fill_color":{"value":null},"left":5.853655999999999,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":6.585362999999999},"id":"18145","type":"BoxAnnotation"},{"attributes":{},"id":"18066","type":"LinearScale"},{"attributes":{"bottom":{"field":"bottom"},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"18100","type":"Quad"},{"attributes":{"fill_alpha":{"value":0.25},"fill_color":{"value":"gray"},"left":0.0,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":2.926827999999999},"id":"18129","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":21.219503,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":21.95121},"id":"18166","type":"BoxAnnotation"},{"attributes":{},"id":"18083","type":"WheelZoomTool"},{"attributes":{"fill_color":{"value":null},"left":2.926827999999999,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":3.6585349999999988},"id":"18141","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":14.63414,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":15.365847},"id":"18157","type":"BoxAnnotation"},{"attributes":{},"id":"18082","type":"SaveTool"},{"attributes":{"callback":null,"end":23.414623999999993},"id":"18174","type":"Range1d"},{"attributes":{"fill_color":{"value":null},"left":10.975605,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":11.707312},"id":"18152","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":8.048777,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":8.780484},"id":"18148","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":16.829261,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":17.560968},"id":"18160","type":"BoxAnnotation"},{"attributes":{"bottom":72,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":73},"id":"18113","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":1.4634139999999995,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":2.1951209999999994},"id":"18139","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":8.780484,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":9.512191},"id":"18149","type":"BoxAnnotation"},{"attributes":{},"id":"18095","type":"BasicTickFormatter"},{"attributes":{"fill_color":{"value":null},"left":6.585362999999999,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":7.317069999999999},"id":"18146","type":"BoxAnnotation"},{"att ...

# %%
sequence = generate(
    "basic_rnn.mag",
    melody_rnn_sequence_generator,
    "basic_rnn",
    primer_filename="got_melody.mid",
    total_length_steps=128,
    temperature=1,
    generatedname = "got_melody_basic_rnn",
    show_plot=False)
from IPython.display import HTML
HTML(filename="output/got_melody_basic_rnn.html")
# Out:
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from /var/folders/dm/3kslprps6b736vz2bgdqpwx00000gn/T/tmp11oy41tf/model.ckpt
# Primer time: [0, 4.235282000000001]
# Generation time: [4.235282000000001, 22.588224]
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -166.166565
# Generated midi file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/got_melody_basic_rnn.mid
# Generated plot file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/got_melody_basic_rnn.html
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Plot</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-1.4.0.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="d091d614-f43f-4a6f-af46-a22280688530" data-root-id="18354"></div>
#
#
#
#
#
#         <script type="application/json" id="18415">
#           {"50f405fa-b3d7-44f1-89d5-3d1fef12a124":{"roots":{"references":[{"attributes":{"fill_color":{"value":null},"left":12.705876000000005,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":13.411758000000006},"id":"18332","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":21.176460000000002,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":21.882342},"id":"18344","type":"BoxAnnotation"},{"attributes":{"bottom":71,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":72},"id":"18296","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":2.823528,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":3.52941},"id":"18318","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":9.176466000000001,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":9.882348000000002},"id":"18327","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":15.529404000000008,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":16.23528600000001},"id":"18336","type":"BoxAnnotation"},{"attributes":{"callback":null,"end":76,"start":63},"id":"18353","type":"Range1d"},{"attributes":{"render_mode":"css","text":"70","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":70.1},"id":"18295","type":"Label"},{"attributes":{"fill_alpha":{"value":0.05},"fill_color":{"value":"gray"},"left":14.117640000000007,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":16.941168000000008},"id":"18311","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":14.823522000000008,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":15.529404000000008},"id":"18335","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"67","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":67.1},"id":"18289","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":3.52941,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":4.235292},"id":"18319","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":16.941168000000008,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":17.647050000000007},"id":"18338","type":"BoxAnnotation"},{"attributes":{},"id":"18243","type":"LinearScale"},{"attributes":{"data_source":{"id":"18274","type":"ColumnDataSource"},"glyph":{"id":"18276","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"18277","type":"Quad"},"selection_glyph":null,"view":{"id":"18279","type":"CDSView"}},"id":"18278","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":22.588224},"id":"18352","type":"Range1d"},{"attributes":{"interval":1},"id":"18346","type":"SingleIntervalTicker"},{"attributes":{"bottom":73,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":74},"id":"18300","type":"BoxAnnotation"},{"attributes":{"bottom":{"field":"bottom"},"fill_color":{"field":"color"},"left":{"field":"left"},"right":{"field":"right"},"top":{"field":"top"}},"id":"18276","type":"Quad"},{"attributes":{"bottom":66,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":67},"id":"18286","type":"BoxAnnotation"},{"attributes":{},"id":"18253","type":"BasicTicker"},{"attributes":{"children":[{"id":"18238","subtype":"Figure","type":"Plot"}]},"id":"18354","type":"Column"},{"attributes":{"bottom":63,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":64},"id":"18280","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.25},"fill_color":{"value":"gray"},"left":11.29411200 ...

# %% [markdown]
# As you can see, in the music generated in basic_rnn for Fur Elis and the Game of Thrones theme, the primer melody is not very evident in the music generated. The only recongnisable aspects of the music are the recycled notes, tempo, and the spacing of the notes which somewhat matches the melody. We will next use two different modified RNN methods that might give us a song that sounds more human and natural.

# %% [markdown]
# ## Lookback RNN
#
# Lookback RNN uses custom inputs and labels in order to train the model better. This specific method uses pattern recognition to generate notes in a less random way. It recognizes patters that occur in the primer melody by "looking back" at the melody one or two bars ago. Along with the same input and labels that basic RNN uses, Lookback RNN uses the previous events from 1 and 2 bars ago as aditional inputs. This gives the network more data points to find patterns, such as small melodies, and mirrored or constrasting melodies and cadences. Lookback RNN also uses the whether the last event was a repetition from the event from 1 or 2 bars ago as an input. This lets the program recognise repetition and determine which segements of the inputed music are single melodies.
# <br>
# In addition to new inouts, we also get more labels with Lookback. These labels, unlike the Basic RNN, look back even further, 1 and 2 bars ago. If the current event is repeating the same event, aka the same sequence of notes, from 2 or 1 bars ago, we use a label to mark that spot as a repetition. On an event where there is no repetition, Lookback marks it with a label as a specific melody. For example, if we have a melody where the third bar repeats the first or second bar, each label for the third bar will be labeled as a repeated melody. But if the fouth bar is a unique melody, it is marked as uniqle. Lookback uses these new labels and inputs to map out the general structure of the input song, and create a some that has more structure.

# %%
sequence = generate(
    "lookback_rnn.mag",
    melody_rnn_sequence_generator,
    "lookback_rnn",
    primer_filename="fur_elis.mid",
    total_length_steps=128,
    temperature=1,
    generatedname = "fur_elis_lookback_rnn",
    show_plot=False)
HTML(filename="output/fur_elis_lookback_rnn.html")
# Out:
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from /var/folders/dm/3kslprps6b736vz2bgdqpwx00000gn/T/tmpl4_l6cl_/model.ckpt
# Primer time: [0, 1.6463307499999995]
# Generation time: [1.6463307499999995, 23.414623999999993]
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -108.476913
# Generated midi file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/fur_elis_lookback_rnn.mid
# Generated plot file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/fur_elis_lookback_rnn.html
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Plot</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-1.4.0.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="5e650189-0cbc-4612-bb1f-0120bfdca0ac" data-root-id="18536"></div>
#
#
#
#
#
#         <script type="application/json" id="18597">
#           {"9d4011bb-f3cb-45f3-8aef-d9799ce6eee6":{"roots":{"references":[{"attributes":{"bottom":73,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":74},"id":"18470","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"77","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":77.1},"id":"18479","type":"Label"},{"attributes":{"render_mode":"css","text":"73","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":73.1},"id":"18471","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":19.024382,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":19.756089},"id":"18522","type":"BoxAnnotation"},{"attributes":{"bottom":70,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":71},"id":"18464","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":8.048777,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":8.780484},"id":"18507","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":13.170726,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":13.902433},"id":"18514","type":"BoxAnnotation"},{"attributes":{},"id":"18437","type":"SaveTool"},{"attributes":{"fill_color":{"value":null},"left":20.487796,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":21.219503},"id":"18524","type":"BoxAnnotation"},{"attributes":{"bottom":79,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":80},"id":"18482","type":"BoxAnnotation"},{"attributes":{"bottom":69,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":70},"id":"18462","type":"BoxAnnotation"},{"attributes":{"bottom":67,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":68},"id":"18458","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":13.902433,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":14.63414},"id":"18515","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":16.097554,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":16.829261},"id":"18518","type":"BoxAnnotation"},{"attributes":{"callback":null,"end":82,"start":67},"id":"18535","type":"Range1d"},{"attributes":{"render_mode":"css","text":"70","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":70.1},"id":"18465","type":"Label"},{"attributes":{"render_mode":"css","text":"76","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":76.1},"id":"18477","type":"Label"},{"attributes":{"grid_line_color":null,"ticker":{"id":"18426","type":"BasicTicker"}},"id":"18429","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.25},"fill_color":{"value":"gray"},"left":5.853655999999999,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":8.780483999999998},"id":"18490","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":10.975605,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":11.707312},"id":"18511","type":"BoxAnnotation"},{"attributes":{"bottom":81,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":82},"id":"18486","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":19.756089,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":20.487796},"id":"18523","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"68","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":68.1},"id":"18461","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":7.317 ...

# %%
sequence = generate(
    "lookback_rnn.mag",
    melody_rnn_sequence_generator,
    "lookback_rnn",
    primer_filename="got_melody.mid",
    total_length_steps=128,
    temperature=1,
    generatedname = "got_melody_lookback_rnn",
    show_plot=False)
from IPython.display import HTML
HTML(filename="output/got_melody_lookback_rnn.html")
# Out:
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from /var/folders/dm/3kslprps6b736vz2bgdqpwx00000gn/T/tmptg5j1w0o/model.ckpt
# Primer time: [0, 4.235282000000001]
# Generation time: [4.235282000000001, 22.588224]
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -271.492767
# Generated midi file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/got_melody_lookback_rnn.mid
# Generated plot file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/got_melody_lookback_rnn.html
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Plot</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-1.4.0.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="ec4c203e-cb5f-42df-b033-c9fcaf239306" data-root-id="18728"></div>
#
#
#
#
#
#         <script type="application/json" id="18789">
#           {"88a352cb-0796-4893-8299-ff745574610e":{"roots":{"references":[{"attributes":{"bottom":63,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":64},"id":"18646","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":11.999994000000004,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":12.705876000000005},"id":"18705","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":14.823522000000008,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":15.529404000000008},"id":"18709","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"72","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":72.1},"id":"18665","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":3.52941,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":4.235292},"id":"18693","type":"BoxAnnotation"},{"attributes":{"bottom":78,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":79},"id":"18676","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.25},"fill_color":{"value":"gray"},"left":16.941168000000008,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":19.764696000000008},"id":"18686","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":11.294112000000004,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":11.999994000000004},"id":"18704","type":"BoxAnnotation"},{"attributes":{"bottom":62,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":63},"id":"18644","type":"BoxAnnotation"},{"attributes":{"bottom":75,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":76},"id":"18670","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":6.352938,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":7.05882},"id":"18697","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.25},"fill_color":{"value":"gray"},"left":0.0,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":2.823528},"id":"18680","type":"BoxAnnotation"},{"attributes":{},"id":"18608","type":"BasicTicker"},{"attributes":{"render_mode":"css","text":"62","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":62.1},"id":"18645","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":16.23528600000001,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":16.941168000000008},"id":"18711","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":21.882342,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":22.588224},"id":"18719","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"61","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":61.1},"id":"18643","type":"Label"},{"attributes":{"bottom":76,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":77},"id":"18672","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":9.176466000000001,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":9.882348000000002},"id":"18701","type":"BoxAnnotation"},{"attributes":{"bottom":72,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":73},"id":"18664","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":2.823528,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":3.52941},"id":"18692","type":"BoxAnnotation"},{"attributes":{"fill_ ...

# %% [markdown]
# As we can see, the two melodies that we created with lookback, comapred to the basic RNN, are much more structured. We can see that our algorithm understood which segments were unique and should be repeated. Unlike in Basic RNN, you could clearly hear the infulence of our primer music in the generated music. However, we can see that for some songs, like Fur Elis, Lookback makes our song too repetitive.

# %% [markdown]
# ## Attention RNN
#
# Attention RNN is a method where "attention" is given to specific parts of the sequence. In this Attention RNN version, where we don’t have an encoder-decoder, we just always look at the outputs from the last 𝑛 steps when generating the output for the current step. The way we “look at” these steps is with an attention mechanism. Specifically:
# <br>
# ![title](images/equation.png)
# <br>
#
# The vector 𝑣 and matrices 𝑊′1, 𝑊′2 are the learnable parameters of the model. ℎ𝑖 are the RNN outputs from the previous 𝑛 steps (ℎ𝑡−𝑛,...,ℎ𝑡−1), and vector 𝑐𝑡 is the current step’s RNN cell state. These are used to calculate 𝑢𝑡𝑖(𝑢𝑡𝑡−𝑛,...,𝑢𝑡𝑡−1), which is an 𝑛 length vector with a value for each of the previous 𝑛 steps. The values is how much attention each step should receive. A softmax is used to normalize these values and create a mask-like vector 𝑎𝑡𝑖, called the attention mask. The RNN outputs from the previous 𝑛 steps are then multiplied by these attention mask values and then summed together to get ℎ′𝑡. The ℎ′𝑡 vector is a vector of the 𝑛 previous outputs combined together, but each output contributing a different amount relative to how much attention that step received.
# <br>
# Using the h't vector, which combines the ouputs of the last n steps, lets Attention RNN injsect information from previous steps into the current step's calculation, letting Attention RNN learn longer-term patterns. It also stores the information from previous steps in the RNN's cell state.

# %%
sequence = generate(
    "attention_rnn.mag",
    melody_rnn_sequence_generator,
    "attention_rnn",
    primer_filename="fur_elis.mid",
    total_length_steps=128,
    temperature=1,
    generatedname = "fur_elis_attention_rnn",
    show_plot=False)
HTML(filename="output/fur_elis_attention_rnn.html")
# Out:
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from /var/folders/dm/3kslprps6b736vz2bgdqpwx00000gn/T/tmpcx3q0x96/model.ckpt
# Primer time: [0, 1.6463307499999995]
# Generation time: [1.6463307499999995, 23.414623999999993]
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -164.623672
# Generated midi file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/fur_elis_attention_rnn.mid
# Generated plot file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/fur_elis_attention_rnn.html
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Plot</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-1.4.0.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="a16cc371-c908-4bae-8f30-453c4b15e6e5" data-root-id="18904"></div>
#
#
#
#
#
#         <script type="application/json" id="18965">
#           {"239d61db-4dff-4eaf-a4ec-51e4874c0536":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.05},"fill_color":{"value":"gray"},"left":2.926827999999999,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":5.853655999999998},"id":"18857","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":0.0,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":0.7317069999999998},"id":"18864","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.25},"fill_color":{"value":"gray"},"left":0.0,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":2.926827999999999},"id":"18856","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":20.487796,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":21.219503},"id":"18892","type":"BoxAnnotation"},{"attributes":{},"id":"18800","type":"BasicTicker"},{"attributes":{"bottom":72,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":73},"id":"18838","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":13.170726,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":13.902433},"id":"18882","type":"BoxAnnotation"},{"attributes":{"bottom":74,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":75},"id":"18842","type":"BoxAnnotation"},{"attributes":{"bottom":80,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":81},"id":"18854","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":17.560968,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":18.292675},"id":"18888","type":"BoxAnnotation"},{"attributes":{"callback":null,"data":{"bottom":[77,76,77,76,77,72,75,73,70,70,74,72,73,72,72,70,73,73,72,70,73,72,75,73,70,70,74,72,73,72,76,70,73,73,72,70,77,72,75,73,70,70,74,72,73,72,72,70,73,73,70,72,77,72,75,73,70,70,74,72,73,72,76,70,73,77,75,77,77,78,78,80,81,73,78,78,77,77,79,76,75,77,77,75,73,74,75,75,80,81,73,78,78,77,77,79,76,75,77],"color":["rgb(228, 153, 226)","rgb(244, 175, 244)","rgb(228, 153, 226)","rgb(244, 175, 244)","rgb(228, 153, 226)","rgb(164, 150, 243)","rgb(234, 198, 234)","rgb(255, 255, 255)","rgb(90, 77, 174)","rgb(90, 77, 174)","rgb(235, 223, 235)","rgb(164, 150, 243)","rgb(255, 255, 255)","rgb(164, 150, 243)","rgb(164, 150, 243)","rgb(90, 77, 174)","rgb(255, 255, 255)","rgb(255, 255, 255)","rgb(164, 150, 243)","rgb(90, 77, 174)","rgb(255, 255, 255)","rgb(164, 150, 243)","rgb(234, 198, 234)","rgb(255, 255, 255)","rgb(90, 77, 174)","rgb(90, 77, 174)","rgb(235, 223, 235)","rgb(164, 150, 243)","rgb(255, 255, 255)","rgb(164, 150, 243)","rgb(244, 175, 244)","rgb(90, 77, 174)","rgb(255, 255, 255)","rgb(255, 255, 255)","rgb(164, 150, 243)","rgb(90, 77, 174)","rgb(228, 153, 226)","rgb(164, 150, 243)","rgb(234, 198, 234)","rgb(255, 255, 255)","rgb(90, 77, 174)","rgb(90, 77, 174)","rgb(235, 223, 235)","rgb(164, 150, 243)","rgb(255, 255, 255)","rgb(164, 150, 243)","rgb(164, 150, 243)","rgb(90, 77, 174)","rgb(255, 255, 255)","rgb(255, 255, 255)","rgb(90, 77, 174)","rgb(164, 150, 243)","rgb(228, 153, 226)","rgb(164, 150, 243)","rgb(234, 198, 234)","rgb(255, 255, 255)","rgb(90, 77, 174)","rgb(90, 77, 174)","rgb(235, 223, 235)","rgb(164, 150, 243)","rgb(255, 255, 255)","rgb(164, 150, 243)","rgb(244, 175, 244)","rgb(90, 77, 174)","rgb(255, 255, 255)","rgb(228, 153, 226)","rgb(234, 198, 234)","rgb(228, 153, 226)","rgb(228, 153, 226)","rgb(255, 51, 255)","rgb(255, 51, 255)","rgb(202, 126, 221)","rgb(178, 153, 229)","rgb(255, 255, 255)","rgb(255, 51, 255)","rgb(255, 51, 255)","rgb(228, 153, 226)","rgb(228, 153, 226)","rgb(255, 51, 255)","rgb(244, 175, 244)","rgb(234, 198, 234)","rgb(228, 153, 22 ...

# %%
sequence = generate(
    "attention_rnn.mag",
    melody_rnn_sequence_generator,
    "attention_rnn",
    primer_filename="got_melody.mid",
    total_length_steps=128,
    temperature=1,
    generatedname = "got_melody_attention_rnn",
    show_plot=False)
from IPython.display import HTML
HTML(filename="output/got_melody_attention_rnn.html")
# Out:
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from /var/folders/dm/3kslprps6b736vz2bgdqpwx00000gn/T/tmptn4cp4ds/model.ckpt
# Primer time: [0, 4.235282000000001]
# Generation time: [4.235282000000001, 22.588224]
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -147.267471
# Generated midi file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/got_melody_attention_rnn.mid
# Generated plot file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/got_melody_attention_rnn.html
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Plot</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-1.4.0.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="723e0f2f-478d-4086-b172-994a50c0d9d5" data-root-id="19268"></div>
#
#
#
#
#
#         <script type="application/json" id="19329">
#           {"60d43b81-a729-455e-bc83-ca030c31055d":{"roots":{"references":[{"attributes":{"render_mode":"css","text":"70","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":70.1},"id":"19215","type":"Label"},{"attributes":{"bottom":71,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":72},"id":"19216","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":7.764702,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":8.470584},"id":"19239","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"59","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":59.1},"id":"19193","type":"Label"},{"attributes":{},"id":"19272","type":"UnionRenderers"},{"attributes":{"fill_color":{"value":null},"left":5.647056,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":6.352938},"id":"19236","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.25},"fill_color":{"value":"gray"},"left":11.294112000000004,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":14.117640000000003},"id":"19224","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":17.647050000000007,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":18.352932000000006},"id":"19253","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"63","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":63.1},"id":"19201","type":"Label"},{"attributes":{"fill_alpha":{"value":0.25},"fill_color":{"value":"gray"},"left":16.941168000000008,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":19.764696000000008},"id":"19226","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"65","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":65.1},"id":"19205","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":13.411758000000006,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":14.117640000000007},"id":"19247","type":"BoxAnnotation"},{"attributes":{"callback":null,"data":{"bottom":[73,64,69,71,73,64,69,71,71,64,68,69,71,64,68,71,64,66,68,71,57,68,64,68,57,73,64,57,68,68,66,64,68,73,61,68,73,64,68,61,71,57,68,66,61,57,68,66,64,68,66,68,57,68,73,68,57,73,64,69,59,71,64,68,71,73,64,68,73,64,68,73,71,57,68,73,57,57,64,69,59,68,64,71,57],"color":["rgb(255, 255, 255)","rgb(162, 88, 232)","rgb(106, 0, 181)","rgb(141, 129, 217)","rgb(255, 255, 255)","rgb(162, 88, 232)","rgb(106, 0, 181)","rgb(141, 129, 217)","rgb(141, 129, 217)","rgb(162, 88, 232)","rgb(179, 0, 179)","rgb(106, 0, 181)","rgb(141, 129, 217)","rgb(162, 88, 232)","rgb(179, 0, 179)","rgb(141, 129, 217)","rgb(162, 88, 232)","rgb(173, 90, 215)","rgb(179, 0, 179)","rgb(141, 129, 217)","rgb(234, 198, 234)","rgb(179, 0, 179)","rgb(162, 88, 232)","rgb(179, 0, 179)","rgb(234, 198, 234)","rgb(255, 255, 255)","rgb(162, 88, 232)","rgb(234, 198, 234)","rgb(179, 0, 179)","rgb(179, 0, 179)","rgb(173, 90, 215)","rgb(162, 88, 232)","rgb(179, 0, 179)","rgb(255, 255, 255)","rgb(255, 51, 255)","rgb(179, 0, 179)","rgb(255, 255, 255)","rgb(162, 88, 232)","rgb(179, 0, 179)","rgb(255, 51, 255)","rgb(141, 129, 217)","rgb(234, 198, 234)","rgb(179, 0, 179)","rgb(173, 90, 215)","rgb(255, 51, 255)","rgb(234, 198, 234)","rgb(179, 0, 179)","rgb(173, 90, 215)","rgb(162, 88, 232)","rgb(179, 0, 179)","rgb(173, 90, 215)","rgb(179, 0, 179)","rgb(234, 198, 234)","rgb(179, 0, 179)","rgb(255, 255, 255)","rgb(179, 0, 179)","rgb(234, 198, 234)","rgb(255, 255, 255)","rgb(162, 88, 232)","rgb(106, 0, 181)","rgb(228, 153, 226)","rgb(141, 129, 217)","rgb(162, 88, 232)","rgb(179, 0, 179)","rgb(141, 129, 217)","rgb(255, 255, 255)","rgb(162, 88, 232)","rgb(179, 0, 179)","rgb(255, 255, 255)","rgb(162, 88, 232)","rgb(179, 0, 179)","rgb(255, 255, 255)","rgb(141 ...

# %% [markdown]
# As we can see, the patterns that are repeated span a larger range with Attention RNN, and thus have more variance than Lookback brings. This creates a more natural sounding melody, as there is more variaton allowed, given the larger space that Attention gives to it's pattern detection.

# %% [markdown]
# ## Summary
#
# Through testing three RNN models, we have found that when learning how to train models to make music, we have to create a model that understand how to recognise patterns. The patterns that the model makes have to be recognizable in order to not be a random mess of notes, but also has to be hollistic enough to be able to not repeat too many patterns too frequently.
