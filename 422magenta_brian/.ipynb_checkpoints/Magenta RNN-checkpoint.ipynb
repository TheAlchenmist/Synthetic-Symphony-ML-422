# %% [markdown]
# # Magenta RNN
#
# In this notebook, we will be generating three basic melodies using Magenta and it's three models.

# %%
import math
import os
import time
import warnings

def action_with_warning():
    warnings.warn("should not appear")

with warnings.catch_warnings(record=True):
    action_with_warning()
    
import magenta.music as mm
from magenta.models.melody_rnn import melody_rnn_sequence_generator
from magenta.music import DEFAULT_QUARTERS_PER_MINUTE
from magenta.protobuf.generator_pb2 import GeneratorOptions
from magenta.protobuf.music_pb2 import NoteSequence
from visual_midi import Plotter

def generate(bundle_name: str,
             sequence_generator,
             generator_id: str,
             primer_filename: str = None,
             qpm: float = DEFAULT_QUARTERS_PER_MINUTE,
             total_length_steps: int = 64,
             temperature: float = 1.0,
             beam_size: int = 1,
             branch_factor: int = 1,
             steps_per_iteration: int = 1,
             show_plot: bool = False) -> NoteSequence:
    mm.notebook_utils.download_bundle(bundle_name, "bundles")
    bundle = mm.sequence_generator_bundle.read_bundle_file(os.path.join("bundles", bundle_name))
    generator_map = sequence_generator.get_generator_map()
    generator = generator_map[generator_id](checkpoint=None, bundle=bundle)
    generator.initialize()
    if primer_filename:
        primer_sequence = mm.midi_io.midi_file_to_note_sequence(
          os.path.join("simplemidi", primer_filename))
    else:
        primer_sequence = NoteSequence()
    if primer_sequence.tempos:
        if len(primer_sequence.tempos) > 1:
          raise Exception("No support for multiple tempos")
        qpm = primer_sequence.tempos[0].qpm
    # Calculates the seconds per 1 step, which changes depending on the QPM 
    # value (steps per quarter in generators are mostly 4)
    seconds_per_step = 60.0 / qpm / getattr(generator, "steps_per_quarter", 4)
  
    # Calculates the primer sequence length in steps and time by taking the
    # total time (which is the end of the last note) and finding the next step
    # start time.
    primer_sequence_length_steps = math.ceil(primer_sequence.total_time
                                             / seconds_per_step)
    primer_sequence_length_time = (primer_sequence_length_steps 
                                   * seconds_per_step)
    primer_end_adjust = (0.00001 if primer_sequence_length_time > 0 else 0)
    primer_start_time = 0
    primer_end_time = (primer_start_time
                       + primer_sequence_length_time
                       - primer_end_adjust)
    generation_length_steps = total_length_steps - primer_sequence_length_steps
    if generation_length_steps <= 0:
        raise Exception("Total length in steps too small "
                        + "(" + str(total_length_steps) + ")"
                        + ", needs to be at least one bar bigger than primer "
                        + "(" + str(primer_sequence_length_steps) + ")")
    generation_length_time = generation_length_steps * seconds_per_step
    generation_start_time = primer_end_time
    generation_end_time = (generation_start_time
                           + generation_length_time
                           + primer_end_adjust)
  
    # Showtime
    print("Primer time: ["
          + str(primer_start_time) + ", "
          + str(primer_end_time) + "]")
    print("Generation time: ["
          + str(generation_start_time) + ", "
          + str(generation_end_time) + "]")
    generator_options = GeneratorOptions()
    generator_options.args['temperature'].float_value = temperature
    generator_options.args['beam_size'].int_value = beam_size
    generator_options.args['branch_factor'].int_value = branch_factor
    generator_options.args['steps_per_iteration'].int_value = (
        steps_per_iteration)
    generator_options.generate_sections.add(
        start_time=generation_start_time,
        end_time=generation_end_time)
    sequence = generator.generate(primer_sequence, generator_options)
    
    date_and_time = time.strftime('%Y-%m-%d_%H%M%S')
    generator_name = str(generator.__class__).split(".")[2]
    midi_filename = "%s_%s.mid" % (generator_name, generator_id)
    midi_path = os.path.join("output", midi_filename)
    mm.midi_io.note_sequence_to_midi_file(sequence, midi_path)
    print("Generated midi file: " + str(os.path.abspath(midi_path)))
  
    # Writes the resulting plot file to the output directory
    date_and_time = time.strftime('%Y-%m-%d_%H%M%S')
    generator_name = str(generator.__class__).split(".")[2]
    plot_filename = "%s_%s.html" % (generator_name, generator_id)
    plot_path = os.path.join("output", plot_filename)
    pretty_midi = mm.midi_io.note_sequence_to_pretty_midi(sequence)
    plotter = Plotter()
    if show_plot:
        plotter.show(pretty_midi, plot_path)
    else:
        plotter.save(pretty_midi, plot_path)
    print("Generated plot file: " + str(os.path.abspath(plot_path)))
      
    return sequence

# %%
def action_with_warning():
    warnings.warn("should not appear")

with warnings.catch_warnings(record=True):
    action_with_warning()
sequence = generate(
    "basic_rnn.mag",
    melody_rnn_sequence_generator,
    "basic_rnn",
    primer_filename="twinkle.mid",
    total_length_steps=64,
    temperature=0.9,
    show_plot=True)
from IPython.display import HTML

HTML(filename="output/melody_rnn_basic_rnn.html")
# Out:
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from /var/folders/dm/3kslprps6b736vz2bgdqpwx00000gn/T/tmpgtzrm87_/model.ckpt
# Primer time: [0, 0.87499]
# Generation time: [0.87499, 8.0]
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -48.270866
# Generated midi file: /Users/brian/422magenta/output/melody_rnn_basic_rnn.mid
# Generated plot file: /Users/brian/422magenta/output/melody_rnn_basic_rnn.html
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Plot</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-1.4.0.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="b3ddd07d-2046-42fe-a90d-8fbd06eddeea" data-root-id="2914"></div>
#
#
#
#
#
#         <script type="application/json" id="2975">
#           {"51432276-b2ab-4e32-a428-e5940d3a64f2":{"roots":{"references":[{"attributes":{},"id":"2843","type":"ResetTool"},{"attributes":{"fill_color":{"value":null},"left":5.5,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":6.0},"id":"2901","type":"BoxAnnotation"},{"attributes":{"bottom":61,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":62},"id":"2868","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"68","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":68.1},"id":"2883","type":"Label"},{"attributes":{"axis_label":"time (SEC)","axis_label_text_font_size":{"value":"12px"},"bounds":[0.0,8.0],"formatter":{"id":"2859","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"10px"},"major_tick_line_alpha":{"value":0.9},"major_tick_out":5,"minor_tick_line_alpha":{"value":0},"ticker":{"id":"2906","type":"SingleIntervalTicker"}},"id":"2833","type":"LinearAxis"},{"attributes":{"fill_color":{"value":null},"left":1.0,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":1.5},"id":"2892","type":"BoxAnnotation"},{"attributes":{},"id":"2845","type":"SaveTool"},{"attributes":{},"id":"2831","type":"LinearScale"},{"attributes":{"fill_color":{"value":null},"left":2.5,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":3.0},"id":"2895","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.25},"fill_color":{"value":"gray"},"left":4.0,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":6.0},"id":"2888","type":"BoxAnnotation"},{"attributes":{},"id":"2918","type":"Selection"},{"attributes":{"bottom":68,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":69},"id":"2882","type":"BoxAnnotation"},{"attributes":{},"id":"2839","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.05},"fill_color":{"value":"gray"},"left":2.0,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":4.0},"id":"2887","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":1.5,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":2.0},"id":"2893","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":3.0,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":3.5},"id":"2896","type":"BoxAnnotation"},{"attributes":{},"id":"2859","type":"BasicTickFormatter"},{"attributes":{"render_mode":"css","text":"64","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":64.1},"id":"2875","type":"Label"},{"attributes":{"bottom":62,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":63},"id":"2870","type":"BoxAnnotation"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"2843","type":"ResetTool"},{"id":"2844","type":"HoverTool"},{"id":"2845","type":"SaveTool"},{"id":"2846","type":"WheelZoomTool"},{"id":"2847","type":"PanTool"}]},"id":"2848","type":"Toolbar"},{"attributes":{"interval":1},"id":"2906","type":"SingleIntervalTicker"},{"attributes":{"fill_alpha":{"value":0.25},"fill_color":{"value":"gray"},"left":0.0,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":2.0},"id":"2886","type":"BoxAnnotation"},{"attributes":{"bottom":63,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":64},"id":"2872","type":"BoxAnnotation"},{"attributes":{"bottom":67,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":68},"id":"2880","type":"BoxAnnotation"},{"attributes":{},"id":"2857","type ...

# %%
sequence = generate(
    "lookback_rnn.mag",
    melody_rnn_sequence_generator,
    "lookback_rnn",
    primer_filename="twinkle.mid",
    total_length_steps=64,
    temperature=0.9,
    show_plot=True)
HTML(filename="output/melody_rnn_lookback_rnn.html")
# Out:
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from /var/folders/dm/3kslprps6b736vz2bgdqpwx00000gn/T/tmp7y5ympkt/model.ckpt
# Primer time: [0, 0.87499]
# Generation time: [0.87499, 8.0]
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -29.210907
# Generated midi file: /Users/brian/422magenta/output/melody_rnn_lookback_rnn.mid
# Generated plot file: /Users/brian/422magenta/output/melody_rnn_lookback_rnn.html

# %%
sequence = generate(
    "attention_rnn.mag",
    melody_rnn_sequence_generator,
    "attention_rnn",
    primer_filename="twinkle.mid",
    total_length_steps=64,
    temperature=0.9,
    show_plot=True)
HTML(filename="output/melody_rnn_attention_rnn.html")
# Out:
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from /var/folders/dm/3kslprps6b736vz2bgdqpwx00000gn/T/tmpiogiqsen/model.ckpt
# Primer time: [0, 0.87499]
# Generation time: [0.87499, 8.0]
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -39.709873
# Generated midi file: /Users/brian/422magenta/output/melody_rnn_attention_rnn.mid
# Generated plot file: /Users/brian/422magenta/output/melody_rnn_attention_rnn.html
