# %% [markdown]
# # Magenta RNN
#
# In this notebook, we will be generating three basic melodies using Magenta and it's three models. Magenta usesa Recurring Nural Network, or RNN, to generate it's music. RNN's are a class of feedforward Neural Networks where nodes form a connected graph along of a temporal sequence.

# %%
import math
import os
import time
import warnings

def action_with_warning():
    warnings.warn("should not appear")

with warnings.catch_warnings(record=True):
    action_with_warning()
    
import magenta.music as mm
from magenta.models.melody_rnn import melody_rnn_sequence_generator
from magenta.music import DEFAULT_QUARTERS_PER_MINUTE
from magenta.protobuf.generator_pb2 import GeneratorOptions
from magenta.protobuf.music_pb2 import NoteSequence
from visual_midi import Plotter
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

def generate(bundle_name: str,
             sequence_generator,
             generator_id: str,
             primer_filename: str = None,
             qpm: float = DEFAULT_QUARTERS_PER_MINUTE,
             total_length_steps: int = 64,
             temperature: float = 1.0,
             beam_size: int = 1,
             branch_factor: int = 1,
             steps_per_iteration: int = 1,
             generatedname = str,
             show_plot: bool = False) -> NoteSequence:
    mm.notebook_utils.download_bundle(bundle_name, "bundles")
    bundle = mm.sequence_generator_bundle.read_bundle_file(os.path.join("bundles", bundle_name))
    generator_map = sequence_generator.get_generator_map()
    generator = generator_map[generator_id](checkpoint=None, bundle=bundle)
    generator.initialize()
    if primer_filename:
        primer_sequence = mm.midi_io.midi_file_to_note_sequence(
          os.path.join("simplemidi", primer_filename))
    else:
        primer_sequence = NoteSequence()
    if primer_sequence.tempos:
        if len(primer_sequence.tempos) > 1:
          raise Exception("No support for multiple tempos")
        qpm = primer_sequence.tempos[0].qpm
    # Calculates the seconds per 1 step, which changes depending on the QPM 
    # value (steps per quarter in generators are mostly 4)
    seconds_per_step = 60.0 / qpm / getattr(generator, "steps_per_quarter", 4)
  
    # Calculates the primer sequence length in steps and time by taking the
    # total time (which is the end of the last note) and finding the next step
    # start time.
    primer_sequence_length_steps = math.ceil(primer_sequence.total_time
                                             / seconds_per_step)
    primer_sequence_length_time = (primer_sequence_length_steps 
                                   * seconds_per_step)
    primer_end_adjust = (0.00001 if primer_sequence_length_time > 0 else 0)
    primer_start_time = 0
    primer_end_time = (primer_start_time
                       + primer_sequence_length_time
                       - primer_end_adjust)
    generation_length_steps = total_length_steps - primer_sequence_length_steps
    if generation_length_steps <= 0:
        raise Exception("Total length in steps too small "
                        + "(" + str(total_length_steps) + ")"
                        + ", needs to be at least one bar bigger than primer "
                        + "(" + str(primer_sequence_length_steps) + ")")
    generation_length_time = generation_length_steps * seconds_per_step
    generation_start_time = primer_end_time
    generation_end_time = (generation_start_time
                           + generation_length_time
                           + primer_end_adjust)
  
    # Showtime
    print("Primer time: ["
          + str(primer_start_time) + ", "
          + str(primer_end_time) + "]")
    print("Generation time: ["
          + str(generation_start_time) + ", "
          + str(generation_end_time) + "]")
    generator_options = GeneratorOptions()
    generator_options.args['temperature'].float_value = temperature
    generator_options.args['beam_size'].int_value = beam_size
    generator_options.args['branch_factor'].int_value = branch_factor
    generator_options.args['steps_per_iteration'].int_value = (
        steps_per_iteration)
    generator_options.generate_sections.add(
        start_time=generation_start_time,
        end_time=generation_end_time)
    sequence = generator.generate(primer_sequence, generator_options)
    
    date_and_time = time.strftime('%Y-%m-%d_%H%M%S')
    generator_name = str(generator.__class__).split(".")[2]
    midi_filename = "%s.mid" % (generatedname)
    midi_path = os.path.join("output", midi_filename)
    mm.midi_io.note_sequence_to_midi_file(sequence, midi_path)
    print("Generated midi file: " + str(os.path.abspath(midi_path)))
  
    # Writes the resulting plot file to the output directory
    date_and_time = time.strftime('%Y-%m-%d_%H%M%S')
    generator_name = str(generator.__class__).split(".")[2]
    plot_filename = "%s.html" % (generatedname)
    plot_path = os.path.join("output", plot_filename)
    pretty_midi = mm.midi_io.note_sequence_to_pretty_midi(sequence)
    plotter = Plotter()
    if show_plot:
        plotter.show(pretty_midi, plot_path)
    else:
        plotter.save(pretty_midi, plot_path)
    print("Generated plot file: " + str(os.path.abspath(plot_path)))
      
    return sequence
  
warnings.filterwarnings("ignore")

# %% [markdown]
# This method, generate, takes a RNN function and a midi, and returns a midi generated using said specified model. When generate is called, it takes in several parameters that affect how the music is generated.
# <br>
# <br>
# RNN model: The RNN model that is being used (i.e basic, lookback, or attention)
# <br>
# total_length_step: The length of the sequence of the produced new song. The total new length of the song will be the length of the song that is provided as data, as well as length specified here
# <br>
# qpm: the quarters per minute of music. The default is 60 qpm
# <br>
# temperature: the randomness of the generated melody. <1 is less random and more like the primer melody, while >1 is more random.
# <br>
# beam size: the larger the beam size, the less random the sequence will be, at the cost of time
# <br>
# steps_per_iteration: # of steps at each iteratiron, the larger this value, the less iterations there are in total

# %% [markdown]
# ## Basic RNN
#
# This model is Magenta standard RNN model. As you can see, in this model, the primer melody is not reflected much in the generated music after. This is because the basic RNN configuration uses one-hot coding to represent extected melodies in the LSTM. It can generate a short melody that stays in the key of the sample meoldy, but it has trouble meeking the same feeling and tone of the music, which a human composer would be able to do. Basic RNN is not able to observe and catalogue patterns in music, and thus generate music that does not share many of the music elements that the primer melody has. Basic RNN is not very holistic, and does not concider groups of notes and the small melodies that they create, and instead is more focused on trying to represent the note-by-note changes.
# <br>
# Basic RNN uses two features, inputs and labels, to generate melodies. The input is the previous event, aka the previous note measure, as a vector. The label is the next event, which can either be turning off (not playing anything), no event (if a note is currently playing, continue playing said note, else continue scilence), and a note-on event for every pitch (which also turns off any other note that might be playing). Based on what they input is, the model will select an event that is not too dissimilar from the previous event to make a following note that sounds somewhat similar to the previous note. By chaining these events together, this method forms a new song.

# %%
tf.disable_v2_behavior()
sequence = generate(
    "basic_rnn.mag",
    melody_rnn_sequence_generator,
    "basic_rnn",
    primer_filename="fur_elis.mid",
    total_length_steps=128,
    temperature=1,
    generatedname = "fur_elis_basic_rnn",
    show_plot=False)
from IPython.display import HTML
HTML(filename="output/fur_elis_basic_rnn.html")
# Out:
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from /var/folders/dm/3kslprps6b736vz2bgdqpwx00000gn/T/tmp9vwqzrda/model.ckpt
# Primer time: [0, 1.6463307499999995]
# Generation time: [1.6463307499999995, 23.414623999999993]
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -189.006241
# Generated midi file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/fur_elis_basic_rnn.mid
# Generated plot file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/fur_elis_basic_rnn.html
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Plot</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-1.4.0.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="90b78cfb-3d40-4d1d-ba7c-5bb1238a6ebc" data-root-id="2359"></div>
#
#
#
#
#
#         <script type="application/json" id="2420">
#           {"fa19e5b0-4287-467b-a6f2-fc3cd9db8841":{"roots":{"references":[{"attributes":{"fill_color":{"value":null},"left":5.853655999999999,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":6.585362999999999},"id":"2327","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"68","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":68.1},"id":"2288","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":15.365847,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":16.097554},"id":"2340","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"72","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":72.1},"id":"2296","type":"Label"},{"attributes":{"callback":null,"end":23.414623999999993},"id":"2357","type":"Range1d"},{"attributes":{"bottom":68,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":69},"id":"2287","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"75","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":75.1},"id":"2302","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":14.63414,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":15.365847},"id":"2339","type":"BoxAnnotation"},{"attributes":{},"id":"2252","type":"LinearScale"},{"attributes":{"bottom":{"field":"bottom"},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"2284","type":"Quad"},{"attributes":{"render_mode":"css","text":"71","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":71.1},"id":"2294","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":7.317069999999999,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":8.048777},"id":"2329","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":6.585362999999999,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":7.317069999999999},"id":"2328","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":13.170726,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":13.902433},"id":"2337","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"73","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":73.1},"id":"2298","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":2.1951209999999994,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":2.926827999999999},"id":"2322","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":13.902433,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":14.63414},"id":"2338","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"77","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":77.1},"id":"2306","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":17.560968,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":18.292675},"id":"2343","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"70","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":70.1},"id":"2292","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":19.756089,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":20.487796},"id":"2346","type":"BoxAnnotation"},{"attributes":{},"id":"2268","type":"PanTool"},{"attributes":{"axis_label":"time (SEC)","axis_label_text_font_size":{"value":"12px"},"bounds":[0.0,23.414623999999993],"formatter":{"id":"2279","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"10px"},"major_tick_line_alpha":{"value":0.9},"major_tick_out":5,"minor_tick_line_alpha": ...

# %%
tf.disable_v2_behavior()
sequence = generate(
    "basic_rnn.mag",
    melody_rnn_sequence_generator,
    "basic_rnn",
    primer_filename="got_melody.mid",
    total_length_steps=128,
    temperature=1,
    generatedname = "got_melody_basic_rnn",
    show_plot=False)
from IPython.display import HTML
HTML(filename="output/got_melody_basic_rnn.html")
# Out:
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from /var/folders/dm/3kslprps6b736vz2bgdqpwx00000gn/T/tmpof0gvv0d/model.ckpt
# Primer time: [0, 4.235282000000001]
# Generation time: [4.235282000000001, 22.588224]
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -167.908829
# Generated midi file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/got_melody_basic_rnn.mid
# Generated plot file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/got_melody_basic_rnn.html
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Plot</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-1.4.0.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="01f884ad-0f91-43e1-8b42-a390fd8fad43" data-root-id="2545"></div>
#
#
#
#
#
#         <script type="application/json" id="2606">
#           {"d5115504-7d18-4f83-bf54-5ede2d9a74fe":{"roots":{"references":[{"attributes":{"render_mode":"css","text":"65","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":65.1},"id":"2482","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":3.52941,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":4.235292},"id":"2510","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":15.529404000000008,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":16.23528600000001},"id":"2527","type":"BoxAnnotation"},{"attributes":{"grid_line_color":null,"ticker":{"id":"2431","type":"BasicTicker"}},"id":"2434","type":"Grid"},{"attributes":{"fill_color":{"value":null},"left":5.647056,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":6.352938},"id":"2513","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":14.823522000000008,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":15.529404000000008},"id":"2526","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"69","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":69.1},"id":"2490","type":"Label"},{"attributes":{"fill_alpha":{"value":0.05},"fill_color":{"value":"gray"},"left":2.823528,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":5.647056},"id":"2498","type":"BoxAnnotation"},{"attributes":{"bottom":67,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":68},"id":"2485","type":"BoxAnnotation"},{"attributes":{},"id":"2453","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.05},"fill_color":{"value":"gray"},"left":14.117640000000007,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":16.941168000000008},"id":"2502","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":14.117640000000007,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":14.823522000000008},"id":"2525","type":"BoxAnnotation"},{"attributes":{"dimension":1,"grid_line_color":null,"ticker":{"id":"2436","type":"BasicTicker"}},"id":"2439","type":"Grid"},{"attributes":{"render_mode":"css","text":"56","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":56.1},"id":"2464","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":0.705882,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":1.411764},"id":"2506","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"67","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":67.1},"id":"2486","type":"Label"},{"attributes":{},"id":"2436","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.05},"fill_color":{"value":"gray"},"left":8.470584,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":11.294112},"id":"2500","type":"BoxAnnotation"},{"attributes":{},"id":"2431","type":"BasicTicker"},{"attributes":{"fill_color":{"value":null},"left":16.941168000000008,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":17.647050000000007},"id":"2529","type":"BoxAnnotation"},{"attributes":{"axis_label":"pitch (MIDI)","axis_label_standoff":0,"axis_label_text_font_size":{"value":"12px"},"bounds":[56,73],"formatter":{"id":"2453","type":"BasicTickFormatter"},"major_label_text_alpha":{"value":0},"major_tick_line_alpha":{"value":0.9},"major_tick_out":25,"minor_tick_line_alpha":{"value":0},"ticker":{"id":"2539","type":"SingleIntervalTicker"}},"id":"2435","type":"LinearAxis"},{"attributes":{"render_mode":"css","text":"71","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":71.1},"id":"2494","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":10.5882 ...

# %% [markdown]
# As you can see, in the music generated in basic_rnn for Fur Elis and the Game of Thrones theme, the primer melody is not very evident in the music generated. The only recongnisable aspects of the music are the recycled notes, tempo, and the spacing of the notes which somewhat matches the melody. We will next use two different modified RNN methods that might give us a song that sounds more human and natural.

# %% [markdown]
# ## Lookback RNN
#
# Lookback RNN uses custom inputs and labels in order to train the model better. This specific method uses pattern recognition to generate notes in a less random way. It recognizes patters that occur in the primer melody by "looking back" at the melody one or two bars ago. Along with the same input and labels that basic RNN uses, Lookback RNN uses the previous events from 1 and 2 bars ago as aditional inputs. This gives the network more data points to find patterns, such as small melodies, and mirrored or constrasting melodies and cadences. Lookback RNN also uses the whether the last event was a repetition from the event from 1 or 2 bars ago as an input. This lets the program recognise repetition and determine which segements of the inputed music are single melodies.
# <br>
# In addition to new inouts, we also get more labels with Lookback. These labels, unlike the Basic RNN, look back even further, 1 and 2 bars ago. If the current event is repeating the same event, aka the same sequence of notes, from 2 or 1 bars ago, we use a label to mark that spot as a repetition. On an event where there is no repetition, Lookback marks it with a label as a specific melody. For example, if we have a melody where the third bar repeats the first or second bar, each label for the third bar will be labeled as a repeated melody. But if the fouth bar is a unique melody, it is marked as uniqle. Lookback uses these new labels and inputs to map out the general structure of the input song, and create a some that has more structure.

# %%
tf.disable_v2_behavior()
sequence = generate(
    "lookback_rnn.mag",
    melody_rnn_sequence_generator,
    "lookback_rnn",
    primer_filename="fur_elis.mid",
    total_length_steps=128,
    temperature=1,
    generatedname = "fur_elis_lookback_rnn",
    show_plot=False)
HTML(filename="output/fur_elis_lookback_rnn.html")
# Out:
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from /var/folders/dm/3kslprps6b736vz2bgdqpwx00000gn/T/tmpj1fxya0k/model.ckpt
# Primer time: [0, 1.6463307499999995]
# Generation time: [1.6463307499999995, 23.414623999999993]
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -69.906746
# Generated midi file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/fur_elis_lookback_rnn.mid
# Generated plot file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/fur_elis_lookback_rnn.html
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Plot</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-1.4.0.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="ea51e0b5-07a4-445c-aa93-4af445e90918" data-root-id="2727"></div>
#
#
#
#
#
#         <script type="application/json" id="2788">
#           {"cc4846bf-806d-4fe5-ae87-841cf2f11651":{"roots":{"references":[{"attributes":{"fill_color":{"value":null},"left":5.853655999999999,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":6.585362999999999},"id":"2695","type":"BoxAnnotation"},{"attributes":{"bottom":75,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":76},"id":"2665","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":8.048777,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":8.780484},"id":"2698","type":"BoxAnnotation"},{"attributes":{"axis_label":"pitch (MIDI)","axis_label_standoff":0,"axis_label_text_font_size":{"value":"12px"},"bounds":[67,82],"formatter":{"id":"2639","type":"BasicTickFormatter"},"major_label_text_alpha":{"value":0},"major_tick_line_alpha":{"value":0.9},"major_tick_out":25,"minor_tick_line_alpha":{"value":0},"ticker":{"id":"2721","type":"SingleIntervalTicker"}},"id":"2621","type":"LinearAxis"},{"attributes":{"bottom":74,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":75},"id":"2663","type":"BoxAnnotation"},{"attributes":{},"id":"2731","type":"Selection"},{"attributes":{"fill_color":{"value":null},"left":4.390241999999999,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":5.121948999999999},"id":"2693","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"68","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":68.1},"id":"2652","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":15.365847,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":16.097554},"id":"2708","type":"BoxAnnotation"},{"attributes":{"bottom":71,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":72},"id":"2657","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":2.926827999999999,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":3.6585349999999988},"id":"2691","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":22.682917,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":23.414624},"id":"2718","type":"BoxAnnotation"},{"attributes":{"bottom":{"field":"bottom"},"fill_color":{"field":"color"},"left":{"field":"left"},"right":{"field":"right"},"top":{"field":"top"}},"id":"2645","type":"Quad"},{"attributes":{"render_mode":"css","text":"70","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":70.1},"id":"2656","type":"Label"},{"attributes":{"render_mode":"css","text":"74","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":74.1},"id":"2664","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":21.95121,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":22.682917},"id":"2717","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":7.317069999999999,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":8.048777},"id":"2697","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":16.097554,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":16.829261},"id":"2709","type":"BoxAnnotation"},{"attributes":{"bottom":73,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":74},"id":"2661","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":3.6585349999999988,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":4.390241999999999},"id":"2692","type":"BoxAnnotation"},{"attributes":{"bottom":{"field":"bottom"},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1} ...

# %%
tf.disable_v2_behavior()
sequence = generate(
    "lookback_rnn.mag",
    melody_rnn_sequence_generator,
    "lookback_rnn",
    primer_filename="got_melody.mid",
    total_length_steps=128,
    temperature=1,
    generatedname = "got_melody_lookback_rnn",
    show_plot=False)
from IPython.display import HTML
HTML(filename="output/got_melody_lookback_rnn.html")
# Out:
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from /var/folders/dm/3kslprps6b736vz2bgdqpwx00000gn/T/tmpbde6v36_/model.ckpt
# Primer time: [0, 4.235282000000001]
# Generation time: [4.235282000000001, 22.588224]
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -189.444336
# Generated midi file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/got_melody_lookback_rnn.mid
# Generated plot file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/got_melody_lookback_rnn.html
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Plot</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-1.4.0.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="ce75ce49-d411-4331-9ddb-31239feb83f4" data-root-id="2901"></div>
#
#
#
#
#
#         <script type="application/json" id="2962">
#           {"8bbc8cc8-cb29-41d2-be1f-f1c8ec4db4d6":{"roots":{"references":[{"attributes":{"callback":null,"end":22.588224},"id":"2899","type":"Range1d"},{"attributes":{"bottom":71,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":72},"id":"2849","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.05},"fill_color":{"value":"gray"},"left":8.470584,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":11.294112},"id":"2856","type":"BoxAnnotation"},{"attributes":{"interval":1},"id":"2895","type":"SingleIntervalTicker"},{"attributes":{},"id":"2804","type":"BasicTicker"},{"attributes":{"text":"Visual MIDI (85 QPM, 4/4)","text_font_size":{"value":"14px"}},"id":"2897","type":"Title"},{"attributes":{"callback":null,"tooltips":[["program","@program"],["pitch","@top"],["velocity","@velocity"],["duration","@duration"],["start_time","@left"],["end_time","@right"]]},"id":"2809","type":"HoverTool"},{"attributes":{"fill_color":{"value":null},"left":7.764702,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":8.470584},"id":"2872","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"72","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":72.1},"id":"2852","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":19.764696000000004,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":20.470578000000003},"id":"2889","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"62","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":62.1},"id":"2832","type":"Label"},{"attributes":{},"id":"2812","type":"PanTool"},{"attributes":{"source":{"id":"2825","type":"ColumnDataSource"}},"id":"2830","type":"CDSView"},{"attributes":{},"id":"2808","type":"ResetTool"},{"attributes":{"fill_color":{"value":null},"left":12.705876000000005,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":13.411758000000006},"id":"2879","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":16.941168000000008,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":17.647050000000007},"id":"2885","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"70","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":70.1},"id":"2848","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":18.352932000000006,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":19.058814000000005},"id":"2887","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"71","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":71.1},"id":"2850","type":"Label"},{"attributes":{"render_mode":"css","text":"66","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":66.1},"id":"2840","type":"Label"},{"attributes":{"bottom":67,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":68},"id":"2841","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"2825","type":"ColumnDataSource"},"glyph":{"id":"2827","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2828","type":"Quad"},"selection_glyph":null,"view":{"id":"2830","type":"CDSView"}},"id":"2829","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":null},"left":0.0,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":0.705882},"id":"2861","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":14.117640000000007,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":14.823522000000008},"id":"2881","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":19.058814000000005,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":19.7 ...

# %% [markdown]
# As we can see, the two melodies that we created with lookback, comapred to the basic RNN, are much more structured. We can see that our algorithm understood which segments were unique and should be repeated. Unlike in Basic RNN, you could clearly hear the infulence of our primer music in the generated music. However, we can see that for some songs, like Fur Elis, Lookback makes our song too repetitive.

# %% [markdown]
# ## Attention RNN
#
# Attention RNN is a method where "attention" is given to specific parts of the sequence. In this Attention RNN version, where we don’t have an encoder-decoder, we just always look at the outputs from the last 𝑛 steps when generating the output for the current step. The way we “look at” these steps is with an attention mechanism. Specifically:
# <br>
# ![title](images/equation.png)
# <br>
#
# The vector 𝑣 and matrices 𝑊′1, 𝑊′2 are the learnable parameters of the model. ℎ𝑖 are the RNN outputs from the previous 𝑛 steps (ℎ𝑡−𝑛,...,ℎ𝑡−1), and vector 𝑐𝑡 is the current step’s RNN cell state. These are used to calculate 𝑢𝑡𝑖(𝑢𝑡𝑡−𝑛,...,𝑢𝑡𝑡−1), which is an 𝑛 length vector with a value for each of the previous 𝑛 steps. The values is how much attention each step should receive. A softmax is used to normalize these values and create a mask-like vector 𝑎𝑡𝑖, called the attention mask. The RNN outputs from the previous 𝑛 steps are then multiplied by these attention mask values and then summed together to get ℎ′𝑡. The ℎ′𝑡 vector is a vector of the 𝑛 previous outputs combined together, but each output contributing a different amount relative to how much attention that step received.
# <br>
# Using the h't vector, which combines the ouputs of the last n steps, lets Attention RNN injsect information from previous steps into the current step's calculation, letting Attention RNN learn longer-term patterns. It also stores the information from previous steps in the RNN's cell state.

# %%
tf.disable_v2_behavior()
sequence = generate(
    "attention_rnn.mag",
    melody_rnn_sequence_generator,
    "attention_rnn",
    primer_filename="fur_elis.mid",
    total_length_steps=128,
    temperature=1,
    generatedname = "fur_elis_attention_rnn",
    show_plot=False)
HTML(filename="output/fur_elis_attention_rnn.html")
# Out:
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from /var/folders/dm/3kslprps6b736vz2bgdqpwx00000gn/T/tmplb1kghm5/model.ckpt
# Primer time: [0, 1.6463307499999995]
# Generation time: [1.6463307499999995, 23.414623999999993]
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -175.282730
# Generated midi file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/fur_elis_attention_rnn.mid
# Generated plot file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/fur_elis_attention_rnn.html
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Plot</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-1.4.0.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="0694f2e7-55d9-4919-890b-23a6ada28849" data-root-id="3075"></div>
#
#
#
#
#
#         <script type="application/json" id="3136">
#           {"79c904f3-e9d4-46ea-affb-f1d4e9433ddb":{"roots":{"references":[{"attributes":{"fill_color":{"value":null},"left":5.853655999999999,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":6.585362999999999},"id":"3043","type":"BoxAnnotation"},{"attributes":{},"id":"2973","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.25},"fill_color":{"value":"gray"},"left":17.560968,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":20.487796},"id":"3033","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.05},"fill_color":{"value":"gray"},"left":20.487796,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":23.414624},"id":"3034","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":19.024382,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":19.756089},"id":"3061","type":"BoxAnnotation"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"2982","type":"ResetTool"},{"id":"2983","type":"HoverTool"},{"id":"2984","type":"SaveTool"},{"id":"2985","type":"WheelZoomTool"},{"id":"2986","type":"PanTool"}]},"id":"2987","type":"Toolbar"},{"attributes":{"grid_line_color":null,"ticker":{"id":"2973","type":"BasicTicker"}},"id":"2976","type":"Grid"},{"attributes":{"fill_color":{"value":null},"left":14.63414,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":15.365847},"id":"3055","type":"BoxAnnotation"},{"attributes":{"callback":null,"tooltips":[["program","@program"],["pitch","@top"],["velocity","@velocity"],["duration","@duration"],["start_time","@left"],["end_time","@right"]]},"id":"2983","type":"HoverTool"},{"attributes":{},"id":"2986","type":"PanTool"},{"attributes":{"bottom":74,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":75},"id":"3015","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":3.6585349999999988,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":4.390241999999999},"id":"3040","type":"BoxAnnotation"},{"attributes":{"callback":null,"end":80,"start":69},"id":"3074","type":"Range1d"},{"attributes":{},"id":"2982","type":"ResetTool"},{"attributes":{},"id":"2985","type":"WheelZoomTool"},{"attributes":{"bottom":{"field":"bottom"},"fill_color":{"field":"color"},"left":{"field":"left"},"right":{"field":"right"},"top":{"field":"top"}},"id":"3001","type":"Quad"},{"attributes":{},"id":"3080","type":"UnionRenderers"},{"attributes":{"bottom":69,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":70},"id":"3005","type":"BoxAnnotation"},{"attributes":{"bottom":{"field":"bottom"},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"3002","type":"Quad"},{"attributes":{"source":{"id":"2999","type":"ColumnDataSource"}},"id":"3004","type":"CDSView"},{"attributes":{"callback":null,"data":{"bottom":[77,76,77,76,77,72,75,73,70,73,77,78,77,75,73,72,77,76,77,76,77,72,75,73,70,72,77,78,77,73,80,78,77,76,78,77,75,75,70,73,77,77,76,73,72,73,74,73,75,77,78,77,75,75,70,73,72,70,72,73,70,75,72,73,74,76,78,77,75,75,70,73,77,77,72,73,70,75,72,73,74,76,77,77,75,75,70,73,77,77,80,78,77,75,73,73],"color":["rgb(228, 153, 226)","rgb(244, 175, 244)","rgb(228, 153, 226)","rgb(244, 175, 244)","rgb(228, 153, 226)","rgb(164, 150, 243)","rgb(234, 198, 234)","rgb(255, 255, 255)","rgb(90, 77, 174)","rgb(255, 255, 255)","rgb(228, 153, 226)","rgb(255, 51, 255)","rgb(228, 153, 226)","rgb(234, 198, 234)","rgb(255, 255, 255)","rgb(164, 150, 243)","rgb(228, 153, 226)","rgb(244, 175, 244)","rgb(228, 153, 226)","rgb(244 ...

# %%
tf.disable_v2_behavior()
sequence = generate(
    "attention_rnn.mag",
    melody_rnn_sequence_generator,
    "attention_rnn",
    primer_filename="got_melody.mid",
    total_length_steps=128,
    temperature=1,
    generatedname = "got_melody_attention_rnn",
    show_plot=False)
from IPython.display import HTML
HTML(filename="output/got_melody_attention_rnn.html")
# Out:
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from /var/folders/dm/3kslprps6b736vz2bgdqpwx00000gn/T/tmp546rq3cn/model.ckpt
# Primer time: [0, 4.235282000000001]
# Generation time: [4.235282000000001, 22.588224]
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -157.879898
# Generated midi file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/got_melody_attention_rnn.mid
# Generated plot file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/got_melody_attention_rnn.html
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Plot</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-1.4.0.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="77759887-b644-4eee-8d87-fd99b693cefb" data-root-id="3257"></div>
#
#
#
#
#
#         <script type="application/json" id="3318">
#           {"d8e03c8a-b9c8-4338-9e94-8574b0d23ef0":{"roots":{"references":[{"attributes":{},"id":"3262","type":"UnionRenderers"},{"attributes":{"render_mode":"css","text":"69","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":69.1},"id":"3202","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":6.352938,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":7.05882},"id":"3226","type":"BoxAnnotation"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"3156","type":"ResetTool"},{"id":"3157","type":"HoverTool"},{"id":"3158","type":"SaveTool"},{"id":"3159","type":"WheelZoomTool"},{"id":"3160","type":"PanTool"}]},"id":"3161","type":"Toolbar"},{"attributes":{"render_mode":"css","text":"59","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":59.1},"id":"3182","type":"Label"},{"attributes":{"bottom":72,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":73},"id":"3207","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":4.235292,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":4.941174},"id":"3223","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":21.882342,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":22.588224},"id":"3248","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":15.529404000000008,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":16.23528600000001},"id":"3239","type":"BoxAnnotation"},{"attributes":{"bottom":71,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":72},"id":"3205","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":11.999994000000004,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":12.705876000000005},"id":"3234","type":"BoxAnnotation"},{"attributes":{"bottom":{"field":"bottom"},"fill_color":{"field":"color"},"left":{"field":"left"},"right":{"field":"right"},"top":{"field":"top"}},"id":"3175","type":"Quad"},{"attributes":{"fill_alpha":{"value":0.05},"fill_color":{"value":"gray"},"left":19.764696000000004,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":22.588224000000004},"id":"3216","type":"BoxAnnotation"},{"attributes":{"text":"Visual MIDI (85 QPM, 4/4)","text_font_size":{"value":"14px"}},"id":"3253","type":"Title"},{"attributes":{"render_mode":"css","text":"71","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":71.1},"id":"3206","type":"Label"},{"attributes":{"interval":1},"id":"3251","type":"SingleIntervalTicker"},{"attributes":{"fill_alpha":{"value":0.25},"fill_color":{"value":"gray"},"left":16.941168000000008,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":19.764696000000008},"id":"3215","type":"BoxAnnotation"},{"attributes":{},"id":"3142","type":"LinearScale"},{"attributes":{"fill_color":{"value":null},"left":9.176466000000001,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":9.882348000000002},"id":"3230","type":"BoxAnnotation"},{"attributes":{"bottom":58,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":59},"id":"3179","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"61","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":61.1},"id":"3186","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":18.352932000000006,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":19.058814000000005},"id":"3243","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"3173","type":"ColumnDataSource"} ...

# %% [markdown]
# As we can see, the patterns that are repeated span a larger range with Attention RNN, and thus have more variance than Lookback brings. This creates a more natural sounding melody, as there is more variaton allowed, given the larger space that Attention gives to it's pattern detection.

# %% [markdown]
# ## Summary
#
# Through testing three RNN models, we have found that when learning how to train models to make music, we have to create a model that understand how to recognise patterns. The patterns that the model makes have to be recognizable in order to not be a random mess of notes, but also has to be hollistic enough to be able to not repeat too many patterns too frequently.
