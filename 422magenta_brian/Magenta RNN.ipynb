# %% [markdown]
# # Magenta RNN
#
# In this notebook, we will be generating three basic melodies using Magenta and it's three models.

# %%
import math
import os
import time
import warnings

def action_with_warning():
    warnings.warn("should not appear")

with warnings.catch_warnings(record=True):
    action_with_warning()
    
import magenta.music as mm
from magenta.models.melody_rnn import melody_rnn_sequence_generator
from magenta.music import DEFAULT_QUARTERS_PER_MINUTE
from magenta.protobuf.generator_pb2 import GeneratorOptions
from magenta.protobuf.music_pb2 import NoteSequence
from visual_midi import Plotter

def generate(bundle_name: str,
             sequence_generator,
             generator_id: str,
             primer_filename: str = None,
             qpm: float = DEFAULT_QUARTERS_PER_MINUTE,
             total_length_steps: int = 64,
             temperature: float = 1.0,
             beam_size: int = 1,
             branch_factor: int = 1,
             steps_per_iteration: int = 1,
             generatedname = str,
             show_plot: bool = False) -> NoteSequence:
    mm.notebook_utils.download_bundle(bundle_name, "bundles")
    bundle = mm.sequence_generator_bundle.read_bundle_file(os.path.join("bundles", bundle_name))
    generator_map = sequence_generator.get_generator_map()
    generator = generator_map[generator_id](checkpoint=None, bundle=bundle)
    generator.initialize()
    if primer_filename:
        primer_sequence = mm.midi_io.midi_file_to_note_sequence(
          os.path.join("simplemidi", primer_filename))
    else:
        primer_sequence = NoteSequence()
    if primer_sequence.tempos:
        if len(primer_sequence.tempos) > 1:
          raise Exception("No support for multiple tempos")
        qpm = primer_sequence.tempos[0].qpm
    # Calculates the seconds per 1 step, which changes depending on the QPM 
    # value (steps per quarter in generators are mostly 4)
    seconds_per_step = 60.0 / qpm / getattr(generator, "steps_per_quarter", 4)
  
    # Calculates the primer sequence length in steps and time by taking the
    # total time (which is the end of the last note) and finding the next step
    # start time.
    primer_sequence_length_steps = math.ceil(primer_sequence.total_time
                                             / seconds_per_step)
    primer_sequence_length_time = (primer_sequence_length_steps 
                                   * seconds_per_step)
    primer_end_adjust = (0.00001 if primer_sequence_length_time > 0 else 0)
    primer_start_time = 0
    primer_end_time = (primer_start_time
                       + primer_sequence_length_time
                       - primer_end_adjust)
    generation_length_steps = total_length_steps - primer_sequence_length_steps
    if generation_length_steps <= 0:
        raise Exception("Total length in steps too small "
                        + "(" + str(total_length_steps) + ")"
                        + ", needs to be at least one bar bigger than primer "
                        + "(" + str(primer_sequence_length_steps) + ")")
    generation_length_time = generation_length_steps * seconds_per_step
    generation_start_time = primer_end_time
    generation_end_time = (generation_start_time
                           + generation_length_time
                           + primer_end_adjust)
  
    # Showtime
    print("Primer time: ["
          + str(primer_start_time) + ", "
          + str(primer_end_time) + "]")
    print("Generation time: ["
          + str(generation_start_time) + ", "
          + str(generation_end_time) + "]")
    generator_options = GeneratorOptions()
    generator_options.args['temperature'].float_value = temperature
    generator_options.args['beam_size'].int_value = beam_size
    generator_options.args['branch_factor'].int_value = branch_factor
    generator_options.args['steps_per_iteration'].int_value = (
        steps_per_iteration)
    generator_options.generate_sections.add(
        start_time=generation_start_time,
        end_time=generation_end_time)
    sequence = generator.generate(primer_sequence, generator_options)
    
    date_and_time = time.strftime('%Y-%m-%d_%H%M%S')
    generator_name = str(generator.__class__).split(".")[2]
    midi_filename = "%s.mid" % (generatedname)
    midi_path = os.path.join("output", midi_filename)
    mm.midi_io.note_sequence_to_midi_file(sequence, midi_path)
    print("Generated midi file: " + str(os.path.abspath(midi_path)))
  
    # Writes the resulting plot file to the output directory
    date_and_time = time.strftime('%Y-%m-%d_%H%M%S')
    generator_name = str(generator.__class__).split(".")[2]
    plot_filename = "%s.html" % (generatedname)
    plot_path = os.path.join("output", plot_filename)
    pretty_midi = mm.midi_io.note_sequence_to_pretty_midi(sequence)
    plotter = Plotter()
    if show_plot:
        plotter.show(pretty_midi, plot_path)
    else:
        plotter.save(pretty_midi, plot_path)
    print("Generated plot file: " + str(os.path.abspath(plot_path)))
      
    return sequence
  
#warnings.filterwarnings("ignore")
# Out:
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/magenta/music/note_sequence_io.py:60: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/magenta/pipelines/statistics.py:132: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %% [markdown]
# This method, generate, takes a RNN function and a midi, and returns a midi generated using said specified model. When generate is called, it takes in several parameters that affect how the music is generated.
# <br>
# <br>
# RNN model: The RNN model that is being used (i.e basic, lookback, or attention)
# <br>
# total_length_step: The length of the sequence of the produced new song. The total new length of the song will be the length of the song that is provided as data, as well as length specified here
# <br>
# qpm: the quarters per minute of music. The default is 60 qpm
# <br>
# temperature: the randomness of the generated melody. <1 is less random and more like the primer melody, while >1 is more random.
# <br>
# beam size: the larger the beam size, the less random the sequence will be, at the cost of time
# <br>
# steps_per_iteration: # of steps at each iteratiron, the larger this value, the less iterations there are in total

# %% [markdown]
# ## Basic RNN
#
# This model is Magenta standard rnn model. As you can see, in this model, the primer melody is not reflected much in the generated music after. This is because the basic RNN configuration uses one-hot coding to represent extected melodies in the LSTM. It is not very holistic, and does not concider groups of notes and the small melodies that they create, and instead is more focused on trying to represent the note-by-note changes.

# %%
sequence = generate(
    "basic_rnn.mag",
    melody_rnn_sequence_generator,
    "basic_rnn",
    primer_filename="fur_elis.mid",
    total_length_steps=64,
    temperature=.9,
    generatedname = "fur_elis_basic_rnn",
    show_plot=False)
from IPython.display import HTML
HTML(filename="output/fur_elis_basic_rnn.html")
# Out:
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/magenta/music/notebook_utils.py:196: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/magenta/music/sequence_generator_bundle.py:30: The name tf.gfile.Open is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/magenta/music/model.py:70: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/magenta/music/model.py:71: The name tf.train.import_meta_graph is deprecated. Please use tf.compat.v1.train.import_meta_graph instead.
#
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from /var/folders/dm/3kslprps6b736vz2bgdqpwx00000gn/T/tmp2dqklk8p/model.ckpt
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/magenta/music/sequence_generator.py:159: The name tf.gfile.DeleteRecursively is deprecated. Please use tf.io.gfile.rmtree instead.
#
# Primer time: [0, 1.6463307499999995]
# Generation time: [1.6463307499999995, 11.707311999999995]
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -117.400810
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/magenta/music/midi_io.py:220: The name tf.gfile.Copy is deprecated. Please use tf.io.gfile.copy instead.
#
# Generated midi file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/fur_elis_basic_rnn.mid
# Generated plot file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/fur_elis_basic_rnn.html
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Plot</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-1.4.0.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="d51cc157-566d-49d4-a137-74e7acb00b4d" data-root-id="1089"></div>
#
#
#
#
#
#         <script type="application/json" id="1150">
#           {"42c316ff-2fc7-4401-b601-443f7c6ca245":{"roots":{"references":[{"attributes":{"interval":1},"id":"1081","type":"SingleIntervalTicker"},{"attributes":{"fill_alpha":{"value":0.25},"fill_color":{"value":"gray"},"left":0.0,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":2.926827999999999},"id":"1061","type":"BoxAnnotation"},{"attributes":{},"id":"1093","type":"Selection"},{"attributes":{},"id":"1022","type":"SaveTool"},{"attributes":{"data_source":{"id":"1037","type":"ColumnDataSource"},"glyph":{"id":"1039","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1040","type":"Quad"},"selection_glyph":null,"view":{"id":"1042","type":"CDSView"}},"id":"1041","type":"GlyphRenderer"},{"attributes":{},"id":"1024","type":"PanTool"},{"attributes":{"axis_label":"pitch (MIDI)","axis_label_standoff":0,"axis_label_text_font_size":{"value":"12px"},"bounds":[69,78],"formatter":{"id":"1034","type":"BasicTickFormatter"},"major_label_text_alpha":{"value":0},"major_tick_line_alpha":{"value":0.9},"major_tick_out":25,"minor_tick_line_alpha":{"value":0},"ticker":{"id":"1083","type":"SingleIntervalTicker"}},"id":"1015","type":"LinearAxis"},{"attributes":{"bottom":{"field":"bottom"},"fill_color":{"field":"color"},"left":{"field":"left"},"right":{"field":"right"},"top":{"field":"top"}},"id":"1039","type":"Quad"},{"attributes":{"bottom":{"field":"bottom"},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"1040","type":"Quad"},{"attributes":{},"id":"1094","type":"UnionRenderers"},{"attributes":{"dimension":1,"grid_line_color":null,"ticker":{"id":"1016","type":"BasicTicker"}},"id":"1019","type":"Grid"},{"attributes":{"fill_color":{"value":null},"left":2.1951209999999994,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":2.926827999999999},"id":"1068","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":1.4634139999999995,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":2.1951209999999994},"id":"1067","type":"BoxAnnotation"},{"attributes":{"bottom":69,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":70},"id":"1043","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.05},"fill_color":{"value":"gray"},"left":2.926827999999999,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":5.853655999999998},"id":"1062","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":3.6585349999999988,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":4.390241999999999},"id":"1070","type":"BoxAnnotation"},{"attributes":{"grid_line_color":null,"ticker":{"id":"1011","type":"BasicTicker"}},"id":"1014","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.25},"fill_color":{"value":"gray"},"left":5.853655999999999,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":8.780483999999998},"id":"1063","type":"BoxAnnotation"},{"attributes":{"source":{"id":"1037","type":"ColumnDataSource"}},"id":"1042","type":"CDSView"},{"attributes":{},"id":"1016","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.05},"fill_color":{"value":"gray"},"left":8.780484,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":11.707311999999998},"id":"1064","type":"BoxAnnotation"},{"attributes":{},"id":"1011","type":"BasicTicker"},{"attributes":{"bottom":71,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":72},"id":"1047","type":"BoxAnnotation"},{"attributes":{"axis_label":"time (SEC)","axis_label_text_font_size":{"value":" ...

# %%
sequence = generate(
    "basic_rnn.mag",
    melody_rnn_sequence_generator,
    "basic_rnn",
    primer_filename="got_melody.mid",
    total_length_steps=64,
    temperature=.9,
    generatedname = "got_melody_basic_rnn",
    show_plot=False)
from IPython.display import HTML
HTML(filename="output/got_melody_basic_rnn.html")
# Out:
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from /var/folders/dm/3kslprps6b736vz2bgdqpwx00000gn/T/tmpbozdczgi/model.ckpt
# Primer time: [0, 4.235282000000001]
# Generation time: [4.235282000000001, 11.294112]
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -85.582985
# Generated midi file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/got_melody_basic_rnn.mid
# Generated plot file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/got_melody_basic_rnn.html
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Plot</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-1.4.0.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="b110b9c5-2410-44d3-af35-d425d6f6a234" data-root-id="1241"></div>
#
#
#
#
#
#         <script type="application/json" id="1302">
#           {"305a3673-e0d0-4007-92e3-6fa5daf01189":{"roots":{"references":[{"attributes":{"bottom":72,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":73},"id":"1211","type":"BoxAnnotation"},{"attributes":{},"id":"1174","type":"PanTool"},{"attributes":{"fill_color":{"value":null},"left":3.52941,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":4.235292},"id":"1222","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":7.05882,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":7.764702},"id":"1227","type":"BoxAnnotation"},{"attributes":{"axis_label":"time (SEC)","axis_label_text_font_size":{"value":"12px"},"bounds":[0.0,11.294112],"formatter":{"id":"1186","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"10px"},"major_tick_line_alpha":{"value":0.9},"major_tick_out":5,"minor_tick_line_alpha":{"value":0},"ticker":{"id":"1233","type":"SingleIntervalTicker"}},"id":"1160","type":"LinearAxis"},{"attributes":{"render_mode":"css","text":"71","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":71.1},"id":"1210","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":7.764702,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":8.470584},"id":"1228","type":"BoxAnnotation"},{"attributes":{},"id":"1186","type":"BasicTickFormatter"},{"attributes":{"fill_color":{"value":null},"left":4.235292,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":4.941174},"id":"1223","type":"BoxAnnotation"},{"attributes":{"bottom":69,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":70},"id":"1205","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"68","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":68.1},"id":"1204","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":10.588230000000003,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":11.294112000000004},"id":"1232","type":"BoxAnnotation"},{"attributes":{"bottom":70,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":71},"id":"1207","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":6.352938,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":7.05882},"id":"1226","type":"BoxAnnotation"},{"attributes":{"bottom":{"field":"bottom"},"fill_color":{"field":"color"},"left":{"field":"left"},"right":{"field":"right"},"top":{"field":"top"}},"id":"1189","type":"Quad"},{"attributes":{"bottom":64,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":65},"id":"1195","type":"BoxAnnotation"},{"attributes":{},"id":"1172","type":"SaveTool"},{"attributes":{"fill_color":{"value":null},"left":8.470584,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":9.176466000000001},"id":"1229","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"72","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":72.1},"id":"1212","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":5.647056,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":6.352938},"id":"1225","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"70","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":70.1},"id":"1208","type":"Label"},{"attributes":{"bottom":71,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":72},"id":"1209","type":"BoxAnnotation"},{"attributes":{},"id":"1166","type":"BasicTicker"},{"attributes":{"grid_line_color":null,"ticker":{"id":"1161","type":"BasicTicker"}},"id":"1164","type":"Grid"},{"attributes": ...

# %% [markdown]
# As you can see, in the music generated in basic_rnn for Fur Elis and the Game of Thrones theme, the primer melody is not very evident in the music generated. The only recongnisable aspects of the music are the recycled notes, tempo, and the spacing of the notes which somewhat matches the melody.

# %%
sequence = generate(
    "lookback_rnn.mag",
    melody_rnn_sequence_generator,
    "lookback_rnn",
    primer_filename="fur_elis.mid",
    total_length_steps=64,
    temperature=.9,
    generatedname = "fur_elis_lookback_rnn",
    show_plot=False)
HTML(filename="output/fur_elis_lookback_rnn.html")
# Out:
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from /var/folders/dm/3kslprps6b736vz2bgdqpwx00000gn/T/tmpp25t5jpd/model.ckpt
# Primer time: [0, 1.6463307499999995]
# Generation time: [1.6463307499999995, 11.707311999999995]
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -33.669331
# Generated midi file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/fur_elis_lookback_rnn.mid
# Generated plot file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/fur_elis_lookback_rnn.html
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Plot</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-1.4.0.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="efcddeff-13bb-41d1-9786-c8564fddab54" data-root-id="1389"></div>
#
#
#
#
#
#         <script type="application/json" id="1450">
#           {"95dbd37f-ff8f-4b08-89f8-c9c048a29421":{"roots":{"references":[{"attributes":{"render_mode":"css","text":"69","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":69.1},"id":"1346","type":"Label"},{"attributes":{"render_mode":"css","text":"70","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":70.1},"id":"1348","type":"Label"},{"attributes":{"render_mode":"css","text":"71","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":71.1},"id":"1350","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":4.390241999999999,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":5.121948999999999},"id":"1371","type":"BoxAnnotation"},{"attributes":{"bottom":{"field":"bottom"},"fill_color":{"field":"color"},"left":{"field":"left"},"right":{"field":"right"},"top":{"field":"top"}},"id":"1341","type":"Quad"},{"attributes":{"bottom":69,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":70},"id":"1345","type":"BoxAnnotation"},{"attributes":{"bottom":75,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":76},"id":"1357","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":5.853655999999999,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":6.585362999999999},"id":"1373","type":"BoxAnnotation"},{"attributes":{"bottom":72,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":73},"id":"1351","type":"BoxAnnotation"},{"attributes":{"interval":1},"id":"1383","type":"SingleIntervalTicker"},{"attributes":{"fill_color":{"value":null},"left":8.780484,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":9.512191},"id":"1377","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":10.243898,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":10.975605},"id":"1379","type":"BoxAnnotation"},{"attributes":{"children":[{"id":"1303","subtype":"Figure","type":"Plot"}]},"id":"1389","type":"Column"},{"attributes":{"fill_alpha":{"value":0.05},"fill_color":{"value":"gray"},"left":8.780484,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":11.707311999999998},"id":"1364","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":7.317069999999999,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":8.048777},"id":"1375","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"73","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":73.1},"id":"1354","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":2.926827999999999,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":3.6585349999999988},"id":"1369","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":3.6585349999999988,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":4.390241999999999},"id":"1370","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"1339","type":"ColumnDataSource"},"glyph":{"id":"1341","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1342","type":"Quad"},"selection_glyph":null,"view":{"id":"1344","type":"CDSView"}},"id":"1343","type":"GlyphRenderer"},{"attributes":{"bottom":76,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":77},"id":"1359","type":"BoxAnnotation"},{"attributes":{"grid_line_color":null,"ticker":{"id":"1313","type":"BasicTicker"}},"id":"1316","type":"Grid"},{"attributes":{"bottom":70,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":71},"id":"1347","type":"BoxAnnotation"},{"attributes":{"fi ...

# %%
sequence = generate(
    "lookback_rnn.mag",
    melody_rnn_sequence_generator,
    "lookback_rnn",
    primer_filename="got_melody.mid",
    total_length_steps=64,
    temperature=.9,
    generatedname = "got_melody_lookback_rnn",
    show_plot=False)
from IPython.display import HTML
HTML(filename="output/got_melody_lookback_rnn.html")
# Out:
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from /var/folders/dm/3kslprps6b736vz2bgdqpwx00000gn/T/tmpofsxel1s/model.ckpt
# Primer time: [0, 4.235282000000001]
# Generation time: [4.235282000000001, 11.294112]
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -59.502411
# Generated midi file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/got_melody_lookback_rnn.mid
# Generated plot file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/got_melody_lookback_rnn.html
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Plot</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-1.4.0.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="72a4c248-023d-4e6b-b31a-25dfddb52b91" data-root-id="1541"></div>
#
#
#
#
#
#         <script type="application/json" id="1602">
#           {"42f602ab-302b-41f3-b668-f7ec96eb39d9":{"roots":{"references":[{"attributes":{"fill_color":{"value":null},"left":0.705882,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":1.411764},"id":"1518","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"72","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":72.1},"id":"1512","type":"Label"},{"attributes":{"interval":1},"id":"1533","type":"SingleIntervalTicker"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"1470","type":"ResetTool"},{"id":"1471","type":"HoverTool"},{"id":"1472","type":"SaveTool"},{"id":"1473","type":"WheelZoomTool"},{"id":"1474","type":"PanTool"}]},"id":"1475","type":"Toolbar"},{"attributes":{"fill_alpha":{"value":0.05},"fill_color":{"value":"gray"},"left":2.823528,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":5.647056},"id":"1514","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"63","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":63.1},"id":"1494","type":"Label"},{"attributes":{"grid_line_color":null,"ticker":{"id":"1461","type":"BasicTicker"}},"id":"1464","type":"Grid"},{"attributes":{"axis_label":"time (SEC)","axis_label_text_font_size":{"value":"12px"},"bounds":[0.0,11.294112],"formatter":{"id":"1486","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"10px"},"major_tick_line_alpha":{"value":0.9},"major_tick_out":5,"minor_tick_line_alpha":{"value":0},"ticker":{"id":"1533","type":"SingleIntervalTicker"}},"id":"1460","type":"LinearAxis"},{"attributes":{"fill_color":{"value":null},"left":2.117646,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":2.823528},"id":"1520","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"67","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":67.1},"id":"1502","type":"Label"},{"attributes":{},"id":"1473","type":"WheelZoomTool"},{"attributes":{"render_mode":"css","text":"70","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":70.1},"id":"1508","type":"Label"},{"attributes":{},"id":"1484","type":"BasicTickFormatter"},{"attributes":{},"id":"1546","type":"UnionRenderers"},{"attributes":{"data_source":{"id":"1487","type":"ColumnDataSource"},"glyph":{"id":"1489","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1490","type":"Quad"},"selection_glyph":null,"view":{"id":"1492","type":"CDSView"}},"id":"1491","type":"GlyphRenderer"},{"attributes":{"bottom":68,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":69},"id":"1503","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":10.588230000000003,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":11.294112000000004},"id":"1532","type":"BoxAnnotation"},{"attributes":{"bottom":71,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":72},"id":"1509","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":8.470584,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":9.176466000000001},"id":"1529","type":"BoxAnnotation"},{"attributes":{"callback":null,"tooltips":[["program","@program"],["pitch","@top"],["velocity","@velocity"],["duration","@duration"],["start_time","@left"],["end_time","@right"]]},"id":"1471","type":"HoverTool"},{"attributes":{"callback":null,"data":{"bottom":[73,64,69,71,73,64,69,71,71,64,68,69,71,64,68,71,73,68,71,69,73,64,69,71,73,64,69,71,71,64,68,69,71,64,68,71,73,68,71,69],"color":["rgb(255, 255, 255)","rgb(162, 88, 232)","rgb(106, 0, 181)","rgb(141, 129, 217)","rgb(255, 255, 255)","rgb(162, 88, 232)","rgb(106, 0, 181)","rgb(141, 129, 217)","rgb(141, 129, 217)","rgb(162, 88, 2 ...

# %%
sequence = generate(
    "attention_rnn.mag",
    melody_rnn_sequence_generator,
    "attention_rnn",
    primer_filename="fur_elis.mid",
    total_length_steps=64,
    temperature=.9,
    generatedname = "fur_elis_attention_rnn",
    show_plot=False)
HTML(filename="output/fur_elis_attention_rnn.html")
# Out:
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from /var/folders/dm/3kslprps6b736vz2bgdqpwx00000gn/T/tmpjxejzqgj/model.ckpt
# Primer time: [0, 1.6463307499999995]
# Generation time: [1.6463307499999995, 11.707311999999995]
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -64.867699
# Generated midi file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/fur_elis_attention_rnn.mid
# Generated plot file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/fur_elis_attention_rnn.html
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Plot</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-1.4.0.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="23583ecd-1450-4338-a675-3f0e253f74e2" data-root-id="1709"></div>
#
#
#
#
#
#         <script type="application/json" id="1770">
#           {"b925cd35-fcd1-48a6-9ae2-066325b854f0":{"roots":{"references":[{"attributes":{"bottom":64,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":65},"id":"1645","type":"BoxAnnotation"},{"attributes":{"interval":1},"id":"1701","type":"SingleIntervalTicker"},{"attributes":{"data_source":{"id":"1639","type":"ColumnDataSource"},"glyph":{"id":"1641","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1642","type":"Quad"},"selection_glyph":null,"view":{"id":"1644","type":"CDSView"}},"id":"1643","type":"GlyphRenderer"},{"attributes":{"bottom":81,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":82},"id":"1679","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":8.780484,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":9.512191},"id":"1697","type":"BoxAnnotation"},{"attributes":{"text":"Visual MIDI (82 QPM, 4/4)","text_font_size":{"value":"14px"}},"id":"1705","type":"Title"},{"attributes":{"render_mode":"css","text":"70","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":70.1},"id":"1658","type":"Label"},{"attributes":{"render_mode":"css","text":"64","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":64.1},"id":"1646","type":"Label"},{"attributes":{"fill_alpha":{"value":0.05},"fill_color":{"value":"gray"},"left":2.926827999999999,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":5.853655999999998},"id":"1682","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.25},"fill_color":{"value":"gray"},"left":5.853655999999999,"level":"underlay","line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_width":{"value":2},"right":8.780483999999998},"id":"1683","type":"BoxAnnotation"},{"attributes":{"bottom":{"field":"bottom"},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"1642","type":"Quad"},{"attributes":{"render_mode":"css","text":"67","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":67.1},"id":"1652","type":"Label"},{"attributes":{"bottom":76,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":77},"id":"1669","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":2.926827999999999,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":3.6585349999999988},"id":"1689","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"80","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":80.1},"id":"1678","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":0.0,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":0.7317069999999998},"id":"1685","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"77","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":77.1},"id":"1672","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":0.7317069999999998,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":1.4634139999999995},"id":"1686","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"69","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":69.1},"id":"1656","type":"Label"},{"attributes":{},"id":"1714","type":"UnionRenderers"},{"attributes":{},"id":"1625","type":"WheelZoomTool"},{"attributes":{"fill_color":{"value":null},"left":10.243898,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":10.975605},"id":"1699","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.25},"fill_color":{"value":"gray"},"left":0.0,"level":"underlay","line_alpha":{"value":0.5},"line_color ...

# %%
sequence = generate(
    "attention_rnn.mag",
    melody_rnn_sequence_generator,
    "attention_rnn",
    primer_filename="got_melody.mid",
    total_length_steps=64,
    temperature=.9,
    generatedname = "got_melody_attention_rnn",
    show_plot=False)
from IPython.display import HTML
HTML(filename="output/got_melody_attention_rnn.html")
# Out:
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from /var/folders/dm/3kslprps6b736vz2bgdqpwx00000gn/T/tmpvkxv7gp5/model.ckpt
# Primer time: [0, 4.235282000000001]
# Generation time: [4.235282000000001, 11.294112]
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -92.371651
# Generated midi file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/got_melody_attention_rnn.mid
# Generated plot file: /Users/brian/Synthetic-Symphony-ML-422/422magenta_brian/output/got_melody_attention_rnn.html
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Plot</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-1.4.0.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="14021e1b-cf15-445e-ad6d-62f26c7263f6" data-root-id="1867"></div>
#
#
#
#
#
#         <script type="application/json" id="1928">
#           {"5e3dabd4-23c3-4bea-b2f2-b65f83429788":{"roots":{"references":[{"attributes":{"fill_color":{"value":null},"left":6.352938,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":7.05882},"id":"1852","type":"BoxAnnotation"},{"attributes":{"dimension":1,"grid_line_color":null,"ticker":{"id":"1786","type":"BasicTicker"}},"id":"1789","type":"Grid"},{"attributes":{"bottom":68,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":69},"id":"1829","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":4.941174,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":5.647056},"id":"1850","type":"BoxAnnotation"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"1790","type":"ResetTool"},{"id":"1791","type":"HoverTool"},{"id":"1792","type":"SaveTool"},{"id":"1793","type":"WheelZoomTool"},{"id":"1794","type":"PanTool"}]},"id":"1795","type":"Toolbar"},{"attributes":{"bottom":65,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":66},"id":"1823","type":"BoxAnnotation"},{"attributes":{"bottom":72,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":73},"id":"1837","type":"BoxAnnotation"},{"attributes":{"bottom":60,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":61},"id":"1813","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"67","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":67.1},"id":"1828","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":10.588230000000003,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":11.294112000000004},"id":"1858","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"68","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":68.1},"id":"1830","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":5.647056,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":6.352938},"id":"1851","type":"BoxAnnotation"},{"attributes":{"text":"Visual MIDI (85 QPM, 4/4)","text_font_size":{"value":"14px"}},"id":"1863","type":"Title"},{"attributes":{"bottom":62,"fill_alpha":{"value":0.15},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":63},"id":"1817","type":"BoxAnnotation"},{"attributes":{},"id":"1778","type":"LinearScale"},{"attributes":{"render_mode":"css","text":"60","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":60.1},"id":"1814","type":"Label"},{"attributes":{"render_mode":"css","text":"66","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":66.1},"id":"1826","type":"Label"},{"attributes":{"interval":1},"id":"1861","type":"SingleIntervalTicker"},{"attributes":{},"id":"1804","type":"BasicTickFormatter"},{"attributes":{"bottom":{"field":"bottom"},"fill_color":{"field":"color"},"left":{"field":"left"},"right":{"field":"right"},"top":{"field":"top"}},"id":"1809","type":"Quad"},{"attributes":{"bottom":71,"fill_alpha":{"value":0.0},"fill_color":{"value":"gray"},"level":"underlay","line_color":{"value":"black"},"top":72},"id":"1835","type":"BoxAnnotation"},{"attributes":{"render_mode":"css","text":"63","text_font_size":{"value":"10px"},"x":-18,"x_units":"screen","y":63.1},"id":"1820","type":"Label"},{"attributes":{"fill_color":{"value":null},"left":3.52941,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":4.235292},"id":"1848","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":null},"left":8.470584,"level":"underlay","line_alpha":{"value":0.4},"line_color":{"value":"black"},"right":9.176466000000001},"id":"1855","type":"BoxAnnotation"},{"attributes":{},"id":" ...
